# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import pandas as pd
import datetime as dt

# %%
# 한글 깨짐 현상을 해결
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
with open('../dataset/BIGCON_DATA_ver1.2/SK_DATA.bin', 'rb') as f:
    sk_data = pickle.load(f) 
with open('../dataset/BIGCON_DATA_ver1.2/SH_DATA.bin', 'rb') as f:
    sh_data = pickle.load(f) 
    
# sk 데이터
sk_age = sk_data['SK_AGE']
sk_time = sk_data['SK_TIME']

# sh 데이터
sh_resident = sh_data['SH_RESIDENT']
sh_foreign = sh_data['SH_FOREIGN']

# %% [markdown]
# * [SCORE](#SCORE)
# * [sk](#sk)
# * [sh](#sh)
# * [corr](#corr-함수)
# * [main](#main)
# * [scatter plot](#scatter-plot)

# %% [markdown]
# ## Score

# %%
formula_1= pd.read_csv('../dataset/score/wordcloud_formula1.csv')
covid_all= pd.read_excel('../dataset/COVID/all_covid.xlsx')
event_score= pd.read_csv('../dataset/score/covid_event_score.csv')

formula_1.rename(columns= {'Unnamed: 0': 'DATE'}, inplace=True)
event_score.rename(columns= {'Unnamed: 0': 'DATE', 'Unnamed: 3': '사건명세'}, inplace=True)

# %%
# 데이터타입 맞추기
formula_1.DATE= formula_1.DATE.astype('datetime64')
event_score.DATE= event_score.DATE.astype('datetime64')
event_score.small= event_score.small.astype('int64')

# %%
# 확진자수, 사건해당횟수, 사건지속기간 추가
event_score= pd.merge(event_score, formula_1, on = 'DATE')

# %% [markdown]
# # SCORE

# %%
# covid interval 추가
# 상위 50퍼센트 미만: 0명 - 27명 1점
# 상위 50퍼센트 이상 20퍼센트 미만: 28명 - 107명 3점
# 상위 20퍼센트 이상 10퍼센트 미만: 108명 - 242명 6점
# 상위 10퍼센트 이상 5퍼센트 미만: 243명 - 505명 10점
# 상위 5퍼센트 이상: 506명 - 15점
event_score['covid_interval'] = pd.qcut(event_score.확진자수, [0,0.5,0.8,0.9,0.95,1], labels= [1,3,6,10,20])
event_score.covid_interval = event_score.covid_interval.astype('int64')

# %%
# 요일 추가
event_score['YO'] = event_score['DATE'].map(lambda x: x.weekday())

# %%
# Scoring
event_score['SCORE'] = np.log(100*event_score['covid_interval'] + 100*event_score['big'] + 10*event_score['small'])*(np.log(event_score['확진자수']+1))

# %%
### pd.set_option('display.max_rows', 121)
event_score
# Out:
#           DATE  big  small                                               사건명세  \
# 0   2020-02-01    0      0                                                NaN
# 1   2020-02-02    0      0                                                NaN
# 2   2020-02-03    0      0                                                NaN
# 3   2020-02-04    0      0                                                NaN
# 4   2020-02-05    0      1                                           구리시 최초확진
# 5   2020-02-06    0      1                                           gs홈쇼핑 확진
# 6   2020-02-07    0      0                                                NaN
# 7   2020-02-08    0      0                                                NaN
# 8   2020-02-09    0      0                                                NaN
# 9   2020-02-10    0      0                                                NaN
# 10  2020-02-11    0      0                                                NaN
# 11  2020-02-12    0      0                                                NaN
# 12  2020-02-13    0      0                                                NaN
# 13  2020-02-14    0      0                                                NaN
# 14  2020-02-15    0      1                                               크루즈선
# 15  2020-02-16    0      0                                                NaN
# 16  2020-02-17    0      0                                                NaN
# 17  2020-02-18    0      0                                                NaN
# 18  2020-02-19    0      1                                        대구 신천지 최초확진
# 19  2020-02-20    1      1                                대구 신천지, 청도 대남병원(경북)
# 20  2020-02-21    2      0                                대구 신천지, 청도 대남병원(경북)
# 21  2020-02-22    2      1                            대구 신천지, 청도 대남병원(경북), 부산
# 22  2020-02-23    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 23  2020-02-24    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 24  2020-02-25    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 25  2020-02-26    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 26  2020-02-27    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 27  2020-02-28    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 28  2020-02-29    2      1                          대구 신천지, 청도 대남병원(경북), 전국확산
# 29  2020-03-01    2      1                      대구 신천지, 청도 대남병원(경북), 대림동 최초확진
# 30  2020-03-02    2      1                       대구 신천지, 청도 대남병원(경북), 광양 최초확진
# 31  2020-03-03    2      1                      대구 신천지, 청도 대남병원(경북), 도봉구 최초확진
# 32  2020-03-04    2      1                      대구 신천지, 청도 대남병원(경북), 괴산군 최초확진
# 33  2020-03-05    2      3     대구 신천지, 청도 대남병원(경북), 푸른요양원, 강북구 최초확진, 용산구 최초확진
# 34  2020-03-06    1      1                                    대구 신천지, 분당 제생병원
# 35  2020-03-07    2      6  대구 신천지, 세종정부청사, 분당 제생병원, 한마음아파트 코호트, 의왕 최초확진, ...
# 36  2020-03-08    3      1                   대구 신천지, 세종정부청사, 분당 제생병원, 괴산 집단감염
# 37  2020-03-09    3      4  구로 콜센터, 대구 신천지, 세종정부청사, 분당 제생병원, 분당 서울대병원 확진, ...
# 38  2020-03-10    4      2  구로 콜센터, 대구 신천지, 세종정부청사, 분당 제생병원, 서산 최초확진, 서울 중...
# 39  2020-03-11    4      1       구로 콜센터, 대구 신천지, 세종정부청사, 분당 제생병원, 대구 콜센터 집단감염
# 40  2020-03-12    4      0                    구로 콜센터, 대구 신천지, 세종정부청사, 분당 제생병원
# 41  2020-03-13    3      2  대구 신천지, 세종정부청사, 분당 제생병원, 동대문구 PC방 집단감염, 서울대입구 ...
# 42  2020-03-14    4      0                    구로 콜센터, 대구 신천지, 구로 콜센터, 분당 제생병원
# 43  2020-03-15    2      0                                     구로 콜센터, 대구 신천지
# 44  2020-03-16    1      1                                대구 신천지, 성남 은혜의 강 교회
# 45  2020-03-17    1      2                         대구 신천지, 화순군 최초확진, 홍성군 최초확진
# 46  2020-03-18    1      1                               대구 신천지, 대구 요양병원 집단감염
# 47  2020-03-19    1      1                                대구 신천지, 경주 세무서 집단감염
# 48  2020-03-20    0      1                                       대구 요양병원 집단감염
# 49  2020-03-21    0      0                                                NaN
# 50  2020-03-22    0      1                                         경주 주점 집단감염
# 51  2020-03-23    0      2                                 함안군 최초확진, 진천군 최초확진
# 52  2020-03-24    0      1                                           부여군 최초확진
# 53  2020-03-25    0      2                                 목포시 최초확진, 인제군 최초확진
# 54  2020-03-26    0      0                                                NaN
# 55  2020-03-27    0      1                                         대구 병원 집단감염
# 56  2020-03-28    0      1                                           익산시 최초확진
# 57  2020-03-29    0      1                                           울진군 최초확진
# 58  2020-03-30    0      0                                                NaN
# 59  2020-03-31    0      0                                                NaN
# 60  2020-04-01    0      2                                 철원군 최초확진, 횡성군 최초확진
# 61  2020-04-02    0      0                                                NaN
# 62  2020-04-03    0      3                      가평군 최초확진, 동두천시 최초확진, 사천시 최초확진
# 63  2020-04-04    0      0                                                NaN
# 64  2020-04-05    0      0                                                NaN
# 65  2020-04-06    0      0                                                NaN
# 66  2020-04-07    0      1                                            유흥업소 확진
# 67  2020-04-08    0      0                                                NaN
# 68  2020-04-09    0      0                                                NaN
# 69  2020-04-10    0      0                                                NaN
# 70  2020-04-11    0      0                                                NaN
# 71  2020-04-12    0      0                                                NaN
# 72  2020-04-13    0      0                                                NaN
# 73  2020-04-14    0      0                                                NaN
# 74  2020-04-15    0      0                                                NaN
# 75  2020-04-16    0      0                                                NaN
# 76  2020-04-17    0      0                                                NaN
# 77  2020-04-18    0      1                                           논산훈련소 확진
# 78  2020-04-19    0      1                                           부산의료원 확진
# 79  2020-04-20    0      0                                                NaN
# 80  2020-04-21    0      0                                                NaN
# 81  2020-04-22    0      0                                                NaN
# 82  2020-04-23    0      0                                                NaN
# 83  2020-04-24    0      0                                                NaN
# 84  2020-04-25    0      0                                                NaN
# 85  2020-04-26    0      0                                                NaN
# 86  2020-04-27    0      0                                                NaN
# 87  2020-04-28    0      0                                                NaN
# 88  2020-04-29    0      0                                                NaN
# 89  2020-04-30    0      0                                                NaN
# 90  2020-05-01    0      0                                                NaN
# 91  2020-05-02    0      0                                                NaN
# 92  2020-05-03    0      0                                          생활 속 거리두기
# 93  2020-05-04    0      0                                                NaN
# 94  2020-05-05    0      0                                                NaN
# 95  2020-05-06    0      0                                                NaN
# 96  2020-05-07    0      1                                             이태원 클럽
# 97  2020-05-08    1      0                                             이태원 클럽
# 98  2020-05-09    1      0                                             이태원 클럽
# 99  2020-05-10    1      0                                             이태원 클럽
# 100 2020-05-11    1      0                                             이태원 클럽
# 101 2020-05-12    1      0                                             이태원 클럽
# 102 2020-05-13    1      0                                             이태원 클럽
# 103 2020-05-14    1      0                                             이태원 클럽
# 104 2020-05-15    1      0                                             이태원 클럽
# 105 2020-05-16    1      0                                             이태원 클럽
# 106 2020-05-17    1      0                                             이태원 클럽
# 107 2020-05-18    1      0                                             이태원 클럽
# 108 2020-05-19    1      1                                     이태원 클럽, 삼성서울병원
# 109 2020-05-20    0      1                                           인천 고3 확진
# 110 2020-05-21    0      0                                                NaN
# 111 2020-05-22    0      0                                                NaN
# 112 2020-05-23    0      0                                                NaN
# 113 2020-05-24    0      0                                                NaN
# 114 2020-05-25    0      0                                                NaN
# 115 2020-05-26    0      1                                              부천 쿠팡
# 116 2020-05-27    1      1                                    부천 쿠팡, 대구 고3 확진
# 117 2020-05-28    1      0                                              부천 쿠팡
# 118 2020-05-29    1      0                                              부천 쿠팡
# 119 2020-05-30    1      0                                              부천 쿠팡
# 120 2020-05-31    1      0                                              부천 쿠팡
#
#      확진자수  사건해당횟수  사건지속기간  covid_interval  YO      SCORE
# 0       1       0       0               1   5   3.192061
# 1       3       0       0               1   6   6.384121
# 2       0       0       0               1   0   0.000000
# 3       1       0       0               1   1   3.192061
# 4       3       0       0               1   2   6.516249
# 5       4       0       0               1   3   7.565131
# 6       1       0       0               1   4   3.192061
# 7       0       0       0               1   5   0.000000
# 8       3       0       0               1   6   6.384121
# 9       0       0       0               1   0   0.000000
# 10      1       0       0               1   1   3.192061
# 11      0       0       0               1   2   0.000000
# 12      0       0       0               1   3   0.000000
# 13      0       0       0               1   4   0.000000
# 14      0       0       0               1   5   0.000000
# 15      0       0       0               1   6   0.000000
# 16      1       0       0               1   0   3.192061
# 17      1       0       0               1   1   3.192061
# 18     20       1       1               1   2  14.310718
# 19     53       2       1               3   3  23.998355
# 20    100       2       2               3   4  28.681165
# 21    229       2       3               6   5  36.419003
# 22    169       2       4               6   6  34.394618
# 23    231       2       5               6   0  36.476987
# 24    144       2       6               6   1  33.329356
# 25    284       2       7              10   2  40.123491
# 26    505       2       8              10   3  44.198296
# 27    571       2       9              20   4  48.893118
# 28    813       2      10              20   5  51.610107
# 29   1062       2      11              20   6  53.665359
# 30    600       2      12              20   0  49.273966
# 31    516       2      13              20   1  48.114602
# 32    438       2      14              10   2  43.190062
# 33    518       2      15              20   3  48.200659
# 34    483       3       1              10   4  43.349492
# 35    367       3       2              10   5  42.177018
# 36    248       3       3              10   6  39.603076
# 37    131       3       4               6   0  33.427075
# 38    242       4       1               6   1  38.053501
# 39    114       4       2               6   2  32.824044
# 40    110       4       3               6   3  32.532282
# 41    107       4       4               3   4  30.104790
# 42     76       4       5               3   5  28.456618
# 43     74       4       6               3   6  26.831497
# 44     84       4       7               3   0  26.727688
# 45     93       4       8               3   1  27.442658
# 46    152       4       9               6   2  33.026158
# 47     87       4      10               3   3  26.936362
# 48    147       4      11               6   4  32.049416
# 49     98       4      12               3   5  26.209564
# 50     64       4      13               3   6  23.946674
# 51     76       4      14               3   0  25.056464
# 52    100       4      15               3   1  26.474973
# 53    104       4      16               3   2  26.845537
# 54     91       4      17               3   3  25.791298
# 55    146       4      18               6   4  32.005935
# 56    105       4      19               3   5  26.752156
# 57     78       4      20               3   6  25.065654
# 58    125       4      21               6   0  30.937355
# 59    101       4      22               3   1  26.379839
# 60     89       4      23               3   2  25.956347
# 61     86       4      24               3   3  25.472568
# 62     94       4      25               3   4  26.408354
# 63     81       4      26               3   5  25.134968
# 64     47       4      27               3   6  22.080488
# 65     47       4      28               3   0  22.080488
# 66     53       4      29               3   1  22.883095
# 67     39       4      30               3   2  21.040566
# 68     27       4      31               1   3  15.345369
# 69     30       4      32               3   4  19.586716
# 70     32       4      33               3   5  19.943319
# 71     25       4      34               1   6  15.004089
# 72     27       4      35               1   0  15.345369
# 73     27       4      36               1   1  15.345369
# 74     22       4      37               1   2  14.439484
# 75     22       4      38               1   3  14.439484
# 76     18       4      39               1   4  13.559643
# 77      8       4      40               1   5  10.328011
# 78     13       4      41               1   6  12.404837
# 79      9       4      42               1   0  10.603796
# 80     11       4      43               1   1  11.443418
# 81      8       4      44               1   2  10.118593
# 82      6       4      45               1   3   8.961247
# 83     10       4      46               1   4  11.042716
# 84     10       4      47               1   5  11.042716
# 85     10       4      48               1   6  11.042716
# 86     14       4      49               1   0  12.471032
# 87      9       4      50               1   1  10.603796
# 88      4       4      51               1   2   7.411735
# 89      9       4      52               1   3  10.603796
# 90      6       4      53               1   4   8.961247
# 91     13       4      54               1   5  12.153308
# 92      8       4      55               1   6  10.118593
# 93      3       4      56               1   0   6.384121
# 94      2       4      57               1   1   5.059297
# 95      4       4      58               1   2   7.411735
# 96     12       5       1               1   3  12.056494
# 97     18       5       2               1   4  15.600572
# 98     34       5       3               3   5  21.301742
# 99     35       5       4               3   6  21.470527
# 100    27       5       5               1   0  17.655077
# 101    26       5       6               1   1  17.462390
# 102    29       5       7               3   2  20.378154
# 103    27       5       8               1   3  17.655077
# 104    19       5       9               1   4  15.872340
# 105    13       5      10               1   5  13.982563
# 106    15       5      11               1   6  14.690055
# 107    13       5      12               1   0  13.982563
# 108    32       6       1               3   1  21.035539
# 109    12       6       2               1   2  12.056494
# 110    20       6       3               1   3  14.020544
# 111    23       6       4               1   4  14.635479
# 112    25       6       5               1   5  15.004089
# 113    16       6       6               1   6  13.047430
# 114    19       6       7               1   0  13.795857
# 115    40       7       1               3   1  21.303175
# 116    79       7       2               3   2  26.362961
# 117    58       7       3               3   3  24.430421
# 118    39       7       4               3   4  22.101790
# 119    27       7       5               1   5  17.655077
# 120    35       7       6               3   6  21.470527

# %%
# 월요일
event_score_mon= event_score.query('YO==0')

# 화요일
event_score_tue= event_score.query('YO==1')

# 수요일
event_score_wed= event_score.query('YO==2')

# 목요일
event_score_thu= event_score.query('YO==3')

# 금요일
event_score_fri= event_score.query('YO==4')

# 토요일
event_score_sat= event_score.query('YO==5')

# 일요일
event_score_sun= event_score.query('YO==6')

# %% [markdown]
# #### sk

# %%
# 유동인구 일별 그래프
def sksk(df, flag, code):
    
    if flag:
        sk_s = df.query('(SI_CODE==@code)')
    else:
        sk_s = df
        
    age_col_list = sk_s.columns.values.tolist()
    age_col_list = age_col_list[7:22]

    temp_df = pd.DataFrame(sk_s.groupby(['DATE'])[age_col_list].sum())
    temp_df = temp_df.sum(axis=1)
    temp_df = temp_df.to_frame(name='Popul')
    pop_df = temp_df.reset_index()
    pop_df['YO'] = pop_df['DATE'].map(lambda x: x.weekday())
    
    # 2020년만 해당하도록 함
    pop_20 = pop_df.tail(121)
    
    # 그래프 보고싶으면 주석처리 빼기
#     draw(pop_20, 'DATE', 'Popul')
    
    return pop_20

# %% [markdown]
# #### sh

# %%
# 매출액 일별 그래프
def shsh(df, flag, code):
    
    if flag:
        sh_s = df.query('(SI_CODE==@code)')
    else:
        sh_s = df
    
    temp_df = pd.DataFrame(sh_s.groupby(['DATE'])['USE_AMT'].sum())
    amt_df = temp_df.reset_index()
    amt_df['YO'] = amt_df['DATE'].map(lambda x: x.weekday())
    
    # 2020년만 해당하도록 함
    amt_20 = amt_df.tail(121)
    
    # 그래프 보고싶으면 주석처리 빼기
#     draw(amt_20, 'DATE', 'USE_AMT')
    
    return amt_20

# %%
def draw(df, x_col, y_col):
    label = df[x_col]
    index = range(len(label))

    plt.figure(figsize=(30,10))
    plt.plot(index, df[y_col], '>-')
    plt.xticks(index[::7], label[::7], rotation='45')
    plt.grid(axis='x')
    plt.show()

# %% [markdown]
# #### corr 함수

# %%
def corr(dataframe, sk_dataframe, sh_dataframe, title):
    
    # Series로 넣는 경우는 .tolist()가 필요
    # list로 넣는경우는 .tolist() 삭제
    origin = pd.DataFrame({'covid':dataframe.tolist(), 'pop':sk_dataframe.tolist(), 'amt':sh_dataframe.tolist()})
    origin_df = origin.corr()

    plt.figure(figsize=(8,8))

    mask = np.zeros_like(origin_df, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    sns.heatmap(origin_df, annot=True, fmt = '.2f', linewidths=.5, cmap='RdYlBu_r', mask=mask, annot_kws={"fontsize":15})
    plt.title(title)
    plt.show()

# %% [markdown]
# ### main

# %%
# 유동인구 

# 2020년 전체(서울+대구)
total_sk = sksk(sk_age, False, '00')

# 2020년 서울
seoul_sk = sksk(sk_age, True, '11')

# 2020년 대구
daegu_sk = sksk(sk_age, True, '27')

# %%
# 매출액

# 2020년 전체(서울+대구)
total_sh = shsh(sh_resident, False, '00')

# 2020년 서울
seoul_sh = shsh(sh_resident, True, '11')

# 2020년 대구
daegu_sh = shsh(sh_resident, True, '27')

# %%
# 전체 유동인구
# 월요일
total_sk_mon= total_sk.query('YO==0')
# 화요일
total_sk_tue= total_sk.query('YO==1')
# 수요일
total_sk_wed= total_sk.query('YO==2')
# 목요일
total_sk_thu= total_sk.query('YO==3')
# 금요일
total_sk_fri= total_sk.query('YO==4')
# 토요일
total_sk_sat= total_sk.query('YO==5')
# 일요일
total_sk_sun= total_sk.query('YO==6')

# %%
# 전체 매출액
# 월요일
total_sh_mon= total_sh.query('YO==0')
# 화요일
total_sh_tue= total_sh.query('YO==1')
# 수요일
total_sh_wed= total_sh.query('YO==2')
# 목요일
total_sh_thu= total_sh.query('YO==3')
# 금요일
total_sh_fri= total_sh.query('YO==4')
# 토요일
total_sh_sat= total_sh.query('YO==5')
# 일요일
total_sh_sun= total_sh.query('YO==6')

# %% [markdown]
# # 요일별 Heatmap

# %%
# 전체
corr(event_score['SCORE'], total_sk['Popul'], total_sh['USE_AMT'], 'SCORE')
corr(event_score['확진자수'], total_sk['Popul'], total_sh['USE_AMT'], 'COVID')

# %%
# 월요일
corr(event_score_mon['SCORE'], total_sk_mon['Popul'], total_sh_mon['USE_AMT'], 'SCORE')
corr(event_score_mon['확진자수'], total_sk_mon['Popul'], total_sh_mon['USE_AMT'], 'COVID')

# %%
# 화요일
corr(event_score_tue['SCORE'], total_sk_tue['Popul'], total_sh_tue['USE_AMT'], 'SCORE')
corr(event_score_tue['확진자수'], total_sk_tue['Popul'], total_sh_tue['USE_AMT'], 'COVID')

# %%
# 수요일
corr(event_score_wed['SCORE'], total_sk_wed['Popul'], total_sh_wed['USE_AMT'], 'SCORE')
corr(event_score_wed['확진자수'], total_sk_wed['Popul'], total_sh_wed['USE_AMT'], 'COVID')

# %%
# 목요일
corr(event_score_thu['SCORE'], total_sk_thu['Popul'], total_sh_thu['USE_AMT'], 'SCORE')
corr(event_score_thu['확진자수'], total_sk_thu['Popul'], total_sh_thu['USE_AMT'], 'COVID')

# %%
# 금요일
corr(event_score_fri['SCORE'], total_sk_fri['Popul'], total_sh_fri['USE_AMT'], 'SCORE')
corr(event_score_fri['확진자수'], total_sk_fri['Popul'], total_sh_fri['USE_AMT'], 'COVID')

# %%
# 토요일
corr(event_score_sat['SCORE'], total_sk_sat['Popul'], total_sh_sat['USE_AMT'], 'SCORE')
corr(event_score_sat['확진자수'], total_sk_sat['Popul'], total_sh_sat['USE_AMT'], 'COVID')

# %%
def scatter(df1, df2, x_col, y_col):
    plt.figure(figsize=(20,20))
    df1['DATE'] = df1['DATE'].astype(str)
    df2['DATE'] = df2['DATE'].astype(str)
    
    sns.scatterplot(x=x_col, 
                    y=y_col, 
                    s=100, # marker size
                    data = pd.merge(df1, df2, on='DATE'))

    plt.show()

scatter(total_sh, total_sk, 'USE_AMT', 'Popul')

# %%
# Event score와 Population scatterplot
scatter(event_score, total_sk, 'SCORE', 'Popul')

# %%
# Event score와 USE_AMT scatterplot
scatter(event_score, total_sh, 'SCORE', 'USE_AMT')

# %%
scatter(event_score_sat, total_sh_sat,'SCORE','USE_AMT')
# Out:
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\envs\py37\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
