# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML

# %%
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
score_table= pd.read_csv("C:/Users/soohan/bigcontest/dataset/Naver_score_SH.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-4cda886fb1a6> in <module>
#       1 score_table= pd.read_csv("C:/Users/soohan/bigcontest/dataset/Naver_score_SH.csv")
# ----> 2 score_table.DATE= score_table.DATE.astype('datetime64')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5128             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5129                 return self[name]
# -> 5130             return object.__getattribute__(self, name)
#    5131
#    5132     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DATE'

# %%
score_table.rename(columns= {'Unnamed: 0':'DATE', '1': '단계1', '2': '단계2', '3': '단계3', '4': '단계4'}, inplace= True)
score_table.DATE= score_table.DATE.astype('datetime64')

# %%
score_table_1= score_table.assign(score_1= lambda x: 4*x.단계1 + 2*x.단계2 + x.단계3)

# %% [markdown]
# # COVID 추이

# %%
covid_all= pd.read_excel('c:/Users/soohan/bigcontest/dataset/all_covid.xlsx')

# %%
plt.figure(figsize= (20,10))
plt.plot(covid_all.iloc[:,0], covid_all.iloc[:,1])
plt.show()

# %%
covid_all
# Out:
#           DATE  NUM
# 0   2020-02-01    1
# 1   2020-02-02    3
# 2   2020-02-03    0
# 3   2020-02-04    1
# 4   2020-02-05    3
# ..         ...  ...
# 116 2020-05-27   79
# 117 2020-05-28   58
# 118 2020-05-29   39
# 119 2020-05-30   27
# 120 2020-05-31   35
#
# [121 rows x 2 columns]

# %%
pd.concat([covid_all, score_table_1], join='inner')
# Out:
#          DATE
# 0  2020-02-01
# 1  2020-02-02
# 2  2020-02-03
# 3  2020-02-04
# 4  2020-02-05
# ..        ...
# 26 2020-05-27
# 27 2020-05-28
# 28 2020-05-29
# 29 2020-05-30
# 30 2020-05-31
#
# [152 rows x 1 columns]
