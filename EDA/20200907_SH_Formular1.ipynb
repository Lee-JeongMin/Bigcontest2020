# %%
import re
import math
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML

# %%
# display 설정
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
formula_1= pd.read_csv('c:/Users/soohan/bigcontest/dataset/wordcloud_formula1.csv')

# %%
formula_1
# Out:
#      Unnamed: 0  확진자수  사건해당횟수  사건지속기간
# 0    2020-02-01     1       0       0
# 1    2020-02-02     3       0       0
# 2    2020-02-03     0       0       0
# 3    2020-02-04     1       0       0
# 4    2020-02-05     3       0       0
# ..          ...   ...     ...     ...
# 116  2020-05-27    79       7       2
# 117  2020-05-28    58       7       3
# 118  2020-05-29    39       7       4
# 119  2020-05-30    27       7       5
# 120  2020-05-31    35       7       6
#
# [121 rows x 4 columns]

# %%
np.log(formula_1['확진자수'])
# Out:
# C:\Users\soohan\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0      0.000000
# 1      1.098612
# 2          -inf
# 3      0.000000
# 4      1.098612
#          ...
# 116    4.369448
# 117    4.060443
# 118    3.663562
# 119    3.295837
# 120    3.555348
# Name: 확진자수, Length: 121, dtype: float64

# %%
pd.set_option('display.max_rows',1000)
formula_1.assign(score= abs(1-np.exp(formula_1['확진자수']))/(formula_1['사건해당횟수']*abs(np.log(1/formula_1['사건지속기간'])+0.005)))
# Out:
# C:\Users\soohan\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#      Unnamed: 0  확진자수  사건해당횟수  사건지속기간          score
# 0    2020-02-01     1       0       0            NaN
# 1    2020-02-02     3       0       0            NaN
# 2    2020-02-03     0       0       0            NaN
# 3    2020-02-04     1       0       0            NaN
# 4    2020-02-05     3       0       0            NaN
# 5    2020-02-06     4       0       0            NaN
# 6    2020-02-07     1       0       0            NaN
# 7    2020-02-08     0       0       0            NaN
# 8    2020-02-09     3       0       0            NaN
# 9    2020-02-10     0       0       0            NaN
# 10   2020-02-11     1       0       0            NaN
# 11   2020-02-12     0       0       0            NaN
# 12   2020-02-13     0       0       0            NaN
# 13   2020-02-14     0       0       0            NaN
# ...
