# %%
import re
import math
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML

# %%
# display 설정
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
formula_1= pd.read_csv('c:/Users/soohan/bigcontest/dataset/wordcloud_formula1.csv')
covid_all= pd.read_excel('c:/Users/soohan/bigcontest/dataset/COVID/all_covid.xlsx')

# %%
formula_1= formula_1.rename(columns={'Unnamed: 0': 'DATE'})
formula_1.DATE= formula_1.DATE.astype('datetime64')

# %%
pd.set_option('display.max_rows',1000)
score_1= formula_1.assign(score= abs(1-np.exp(formula_1['확진자수']))/(formula_1['사건해당횟수']*abs(np.log(1/formula_1['사건지속기간'])+0.005)))
# Out:
# C:\Users\soohan\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: overflow encountered in exp
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
merged= pd.merge(score_1, covid_all)

# %%
merged= merged.fillna(0)

# %%
merged
# Out:
#           DATE  확진자수  사건해당횟수  사건지속기간          score   NUM
# 0   2020-02-01     1       0       0   0.000000e+00     1
# 1   2020-02-02     3       0       0   0.000000e+00     3
# 2   2020-02-03     0       0       0   0.000000e+00     0
# 3   2020-02-04     1       0       0   0.000000e+00     1
# 4   2020-02-05     3       0       0   0.000000e+00     3
# 5   2020-02-06     4       0       0   0.000000e+00     4
# 6   2020-02-07     1       0       0   0.000000e+00     1
# 7   2020-02-08     0       0       0   0.000000e+00     0
# 8   2020-02-09     3       0       0   0.000000e+00     3
# 9   2020-02-10     0       0       0   0.000000e+00     0
# 10  2020-02-11     1       0       0   0.000000e+00     1
# 11  2020-02-12     0       0       0   0.000000e+00     0
# 12  2020-02-13     0       0       0   0.000000e+00     0
# 13  2020-02-14     0       0       0   0.000000e+00     0
# 14  2020-02-15     0       0       0   0.000000e+00     0
# ...

# %%
merged.corr()
# Out:
#             확진자수    사건해당횟수    사건지속기간  score       NUM
# 확진자수    1.000000 -0.165221 -0.179196    0.0  1.000000
# 사건해당횟수 -0.165221  1.000000  0.254637   -0.0 -0.165221
# 사건지속기간 -0.179196  0.254637  1.000000   -0.0 -0.179196
# score   0.000000 -0.000000 -0.000000    NaN  0.000000
# NUM     1.000000 -0.165221 -0.179196    0.0  1.000000
