# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager

# %%
path= 'c:/Users/soohan/bigcontest/dataset/BIGCON_DATA_ver1.2'

# %%
with open(path+'/CJ_DATA.bin', 'rb') as f:
    cj = pickle.load(f)

with open(path+'/GS_DATA.bin', 'rb') as f:
    gs = pickle.load(f)
    
with open(path+'/SH_DATA.bin', 'rb') as f:
    sh = pickle.load(f)
    
with open(path+'/SK_DATA.bin', 'rb') as f:
    sk = pickle.load(f)
    
with open(path+'/WS_DATA.bin', 'rb') as f:
    ws = pickle.load(f)

# %%
print(cj.keys())
print('-'*80)
print(gs.keys())
print('-'*80)
print(sh.keys())
print('-'*80)
print(sk.keys())
print('-'*80)
print(ws.keys())
# Out:
# dict_keys(['CJ_DATA', 'ITEM_CODE_DICT', 'COL_CHANGE_DICT', 'GEO_CODE_DICT'])
# --------------------------------------------------------------------------------
# dict_keys(['GS_TOTAL', 'GS_CATEGORY', 'GS_DONG', 'ITEM_CODE_DICT', 'COL_CHANGE_DICT', 'GEO_CODE_DICT'])
# --------------------------------------------------------------------------------
# dict_keys(['SH_RESIDENT', 'SH_FOREIGN', 'INDUSTRY_CODE_DICT', 'COL_CHANGE_DICT', 'GEO_CODE_DICT'])
# --------------------------------------------------------------------------------
# dict_keys(['SK_AGE', 'SK_TIME', 'COL_CHANGE_DICT', 'GEO_CODE_DICT'])
# --------------------------------------------------------------------------------
# dict_keys(['WS_MENTION', 'WS_SENTIMENT', 'WS_TOPIC', 'COL_CHANGE_DICT', 'INDUSTRY_CODE_DICT', 'GEO_CODE_DICT'])

# %%
# cj data
cj_data= cj['CJ_DATA']

# gs data
gs_total_data= gs['GS_TOTAL']
gs_category_data= gs['GS_CATEGORY']
gs_dong_data= gs['GS_DONG']

# sh data
sh_resident_data= sh['SH_RESIDENT']
sh_foreign_data= sh['SH_FOREIGN']

# sk data
sk_age_data= sk['SK_AGE']
sk_time_data= sk['SK_TIME']

# ws data
ws_mention_data= ws['WS_MENTION']
ws_sentiment_data= ws['WS_SENTIMENT']
ws_topic_data= ws['WS_TOPIC']

# %% [markdown]
# # 시각화 설정

# %%
# plt 폰트 설정
path= 'c:/Windows/Fonts/malgun.ttf'
font_name= font_manager.FontProperties(fname= path).get_name()
plt.rcParams['font.family']= font_name

# seaborn 폰트 설정
sns.set(style= 'whitegrid', rc= {'figure.figsize': (10,10)},
       font= font_name)

# %%
len(gs_category_data)
# Out:
# 480

# %%
print("CJ")
print(len(cj_data))
print("-"*80)
print("GS")
print(len(gs_total_data))
print(len(gs_category_data))
print(len(gs_dong_data))
print("-"*80)
print("SH")
print(len(sh_resident_data))
print(len(sh_foreign_data))
print("-"*80)
print('SK')
print(len(sk_age_data))
print(len(sk_time_data))
print("-"*80)
print('WS')
print(len(ws_mention_data))
print(len(ws_sentiment_data))
print(len(ws_topic_data))
# Out:
# CJ
# 156571
# --------------------------------------------------------------------------------
# GS
# 14460
# 480
# 67
# --------------------------------------------------------------------------------
# SH
# 2537753
# 238829
# --------------------------------------------------------------------------------
# SK
# 33258
# 16629
# --------------------------------------------------------------------------------
# WS
# 840
# 3360
# 280

# %%
print("CJ")
print(cj_data.columns)
print("-"*80)
print("GS")
print(gs_total_data.columns)
print(gs_category_data.columns)
print(gs_dong_data.columns)
print("-"*80)
print("SH")
print(sh_resident_data.columns)
print(sh_foreign_data.columns)
print("-"*80)
print('SK')
print(sk_age_data.columns)
print(sk_time_data.columns)
print("-"*80)
print('WS')
print(ws_mention_data.columns)
print(ws_sentiment_data.columns)
print(ws_topic_data.columns)
# Out:
# CJ
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'ITEM_CODE', 'SI_CODE', 'SI_NM',
#        'GU_CODE', 'GU_NM', 'DONG_CODE', 'DONG_NM', 'TRANSIT_COUNT',
#        'TOTAL_CODE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# GS
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'SI_NM', 'GU_NM', 'DONG_NM', 'AMT_IND',
#        'LCLS_10_P', 'LCLS_20_P', 'LCLS_30_P', 'LCLS_40_P', 'LCLS_50_P',
#        'LCLS_60_P', 'LCLS_70_P', 'LCLS_80_P', 'SI_CODE', 'GU_CODE',
#        'DONG_CODE', 'TOTAL_CODE'],
#       dtype='object')
# Index(['SI_NM', 'GU_NM', 'DONG_NM', 'ITEM_CODE', '20190201', '20190202',
#        '20190203', '20190204', '20190205', '20190206',
#        ...
#        '20200526', '20200527', '20200528', '20200529', '20200530', '20200531',
#        'SI_CODE', 'GU_CODE', 'DONG_CODE', 'TOTAL_CODE'],
#       dtype='object', length=249)
# Index(['SI_NM', 'GU_NM', 'DONG_NM', '20190201', '20190202', '20190203',
#        '20190204', '20190205', '20190206', '20190207',
#        ...
#        '20200526', '20200527', '20200528', '20200529', '20200530', '20200531',
#        'SI_CODE', 'GU_CODE', 'DONG_CODE', 'TOTAL_CODE'],
#       dtype='object', length=248)
# --------------------------------------------------------------------------------
# SH
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'GU_CODE', 'DONG_CODE', 'INDUSTRY_CODE',
#        'SEX', 'AGE', 'USE_CNT', 'USE_AMT', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'GU_CODE', 'DONG_CODE', 'INDUSTRY_CODE',
#        'COUNTRY_NM', 'USE_CNT', 'USE_AMT', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# SK
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'DONG_CODE', 'DONG_NM', 'SEX', '00-04',
#        '05-09', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40-44',
#        '45-49', '50-54', '55-59', '60-64', '65-69', '70-00', 'TOTAL_CODE',
#        'SI_CODE', 'GU_CODE'],
#       dtype='object')
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'DONG_CODE', 'DONG_NM', 'TMST_00',
#        'TMST_01', 'TMST_02', 'TMST_03', 'TMST_04', 'TMST_05', 'TMST_06',
#        'TMST_07', 'TMST_08', 'TMST_09', 'TMST_10', 'TMST_11', 'TMST_12',
#        'TMST_13', 'TMST_14', 'TMST_15', 'TMST_16', 'TMST_17', 'TMST_18',
#        'TMST_19', 'TMST_20', 'TMST_21', 'TMST_22', 'TMST_23', 'TOTAL_CODE',
#        'SI_CODE', 'GU_CODE'],
#       dtype='object')
# --------------------------------------------------------------------------------
# WS
# Index(['YEAR', 'MONTH', 'GU_CODE', 'GU_NM', 'DONG_CODE', 'DONG_NM', 'CATEGORY',
#        'CNT', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')
# Index(['YEAR', 'MONTH', 'GU_CODE', 'GU_NM', 'DONG_CODE', 'DONG_NM',
#        'INDUSTRY_CODE', 'SENTIMENT', 'CNT', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')
# Index(['YEAR', 'MONTH', 'GU_CODE', 'GU_NM', 'DONG_CODE', 'DONG_NM',
#        'TOPIC_WORD_LIST', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')

# %% [markdown]
# # CJ DATA

# %%
plt.hist(cj_data.TRANSIT_COUNT)
# Out:
# (array([1.36992e+05, 1.56470e+04, 3.01900e+03, 6.93000e+02, 1.60000e+02,
#         4.10000e+01, 1.40000e+01, 2.00000e+00, 2.00000e+00, 1.00000e+00]),
#  array([1.0000e+00, 2.6760e+02, 5.3420e+02, 8.0080e+02, 1.0674e+03,
#         1.3340e+03, 1.6006e+03, 1.8672e+03, 2.1338e+03, 2.4004e+03,
#         2.6670e+03], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
# datetime 자료형을 일시적으로 string으로 변환
cj_data.DATE = cj_data.DATE.astype('str')

# %%
cj_data_YM = pd.DataFrame.copy(cj_data)

# %%
cj_data_YM.YEAR= cj_data_YM.YEAR.astype('str')
cj_data_YM.MONTH= cj_data_YM.MONTH.astype('str')

# %%
cj_data_YM['YM']= cj_data_YM.YEAR + cj_data_YM.MONTH

# %%
cj_groupby= cj_data_YM.groupby(['YM','GU_CODE'])
cj_groupby_cnt_data= cj_groupby.count().unstack()['TRANSIT_COUNT']

# %%
# YEAR, MONTH별 구 별 TRANSIT_COUNT의 분포
cj_groupby_cnt_data.plot.bar()

# %%
# 구 별 ITEM_CODE 분포
sns.countplot(x= 'GU_CODE',hue= 'ITEM_CODE',data= cj_data, orient= 'h')

# %%
# 구별 transit_count boxplot
cj_groupby_cnt_data.plot.box()

# %% [markdown]
# # GS DATA

# %% [markdown]
# ## GS TOTAL DATA

# %%
gs_total_data
# Out:
#             DATE  YEAR  MONTH  DAY SI_NM GU_NM DONG_NM  AMT_IND  LCLS_10_P  \
# 0     2019-02-01  2019      2    1    대구   수성구    고산1동     1.06      0.451
# 1     2019-02-01  2019      2    1    대구   수성구    고산2동     1.08      0.458
# 2     2019-02-01  2019      2    1    대구   수성구    고산3동     0.86      0.360
# 3     2019-02-01  2019      2    1    대구   수성구     두산동     0.72      0.282
# 4     2019-02-01  2019      2    1    대구   수성구    만촌1동     1.16      0.401
# ...          ...   ...    ...  ...   ...   ...     ...      ...        ...
# 14455 2020-05-31  2020      5   31    서울    중구     중림동     1.60      0.314
# 14456 2020-05-31  2020      5   31    서울    중구     청구동     1.39      0.276
# 14457 2020-05-31  2020      5   31    서울    중구      필동     0.71      0.303
# 14458 2020-05-31  2020      5   31    서울    중구     황학동     1.13      0.265
# 14459 2020-05-31  2020      5   31    서울    중구     회현동     0.77      0.317
#
#        LCLS_20_P  LCLS_30_P  LCLS_40_P  LCLS_50_P  LCLS_60_P  LCLS_70_P  \
# 0          0.172      0.295      0.023      0.045      0.005      0.005
# 1          0.196      0.296      0.006      0.034      0.001      0.009
# 2          0.197      0.377      0.013      0.030      0.009      0.009
# 3          0.175      0.363      0.024      0.134      0.000      0.021
# 4          0.200      0.311      0.039      0.035      0.005      0.006
# ...          ...        ...        ...        ...        ...        ...
# 14455      0.221      0.344      0.026      0.070      0.006      0.014
# 14456      0.221      0.364      0.054      0.077      0.002      0.000
# 14457      0.188      0.370      0.039      0.079      0.008      0.008
# 14458      0.257      0.367      0.029      0.071      0.001      0.004
# 14459      0.160      0.410      0.031      0.071      0.000      0.009
#
#        LCLS_80_P SI_CODE GU_CODE DONG_CODE TOTAL_CODE
# 0          0.004      27      26       670    2726670
# 1          0.001      27      26       680    2726680
# 2          0.006      27      26       690    2726690
# 3          0.000      27      26       640    2726640
# 4          0.003      27      26       550    2726550
# ...          ...     ...     ...       ...        ...
# 14455      0.004      11      14       680    1114680
# 14456      0.006      11      14       645    1114645
# 14457      0.004      11      14       570    1114570
# 14458      0.006      11      14       670    1114670
# 14459      0.002      11      14       540    1114540
#
# [14460 rows x 20 columns]

# %% [markdown]
# ### GU_CODE
# ##### 대구 수성구: 26
# ##### 대구 중구: 11
# ##### 서울 중구: 14
# ##### 서울 노원구: 35

# %%
# 월별, 구별 
gs_total_gb= gs_total_data.groupby(['YEAR','MONTH','GU_CODE'])
gs_total_gb.sum()['AMT_IND'].sort_values().plot.barh()

# %%
# gs total data pairplot
sns.pairplot(gs_total_data.iloc[:,8:16], kind= 'reg', diag_kind= 'kde')
# Out:
# C:\Users\soohan\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\soohan\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# linear model plot
sns.lmplot(x= 'LCLS_10_P', y= 'LCLS_20_P', data= gs_total_data )

# %% [markdown]
# ## GS_CATEGORY_DATA

# %%
gs_category_data
# Out:
#     SI_NM GU_NM DONG_NM ITEM_CODE  20190201  20190202  20190203  20190204  \
# 0      서울    중구     소공동        10     0.288     0.304     0.276     0.356
# 1      서울    중구     소공동        20     0.186     0.227     0.225     0.238
# 2      서울    중구     소공동        30     0.384     0.345     0.272     0.308
# 3      서울    중구     소공동        40     0.042     0.028     0.017     0.015
# 4      서울    중구     소공동        50     0.081     0.084     0.188     0.057
# ..    ...   ...     ...       ...       ...       ...       ...       ...
# 475    대구   수성구    고산3동        40     0.013     0.008     0.012     0.016
# 476    대구   수성구    고산3동        50     0.030     0.056     0.077     0.066
# 477    대구   수성구    고산3동        60     0.009     0.010       NaN     0.007
# 478    대구   수성구    고산3동        70     0.009     0.020     0.009     0.017
# 479    대구   수성구    고산3동        80     0.006     0.006     0.004     0.005
#
#      20190205  20190206  ...  20200526  20200527  20200528  20200529  \
# 0       0.318     0.330  ...     0.248     0.265     0.251     0.240
# 1       0.269     0.209  ...     0.177     0.200     0.196     0.225
# 2       0.319     0.335  ...     0.378     0.429     0.422     0.430
# 3       0.016     0.036  ...     0.046     0.026     0.043     0.027
# 4       0.062     0.069  ...     0.140     0.068     0.075     0.062
# ..        ...       ...  ...       ...       ...       ...       ...
# 475     0.016     0.005  ...     0.003     0.006     0.012     0.011
# 476     0.065     0.064  ...     0.040     0.047     0.048     0.042
# 477     0.016     0.010  ...     0.001     0.016     0.005     0.006
# 478     0.020     0.007  ...     0.007     0.003     0.008       NaN
# 479     0.006     0.004  ...     0.006     0.013     0.005     0.007
#
#      20200530  20200531  SI_CODE  GU_CODE  DONG_CODE  TOTAL_CODE
# 0       0.230     0.325       11       14        520     1114520
# 1       0.213     0.192       11       14        520     1114520
# 2       0.430     0.375       11       14        520     1114520
# 3       0.042     0.020       11       14        520     1114520
# 4       0.070     0.070       11       14        520     1114520
# ..        ...       ...      ...      ...        ...         ...
# 475     0.012     0.035       27       26        690     2726690
# 476     0.045     0.051       27       26        690     2726690
# 477     0.004     0.006       27       26        690     2726690
# 478     0.002     0.008       27       26        690     2726690
# 479     0.004     0.007       27       26        690     2726690
#
# [480 rows x 249 columns]

# %%
gs['ITEM_CODE_DICT'].values()
# Out:
# dict_values(['식사', '간식', '마실거리', '홈&리빙', '헬스&뷰티', '취미&여가활동', '사회활동', '임신/육아'])

# %%
# 구별 관측값 개수
# 26: 160
# 35: 144
# 14: 120
# 11: 56
gs_category_data.GU_CODE.value_counts().plot.bar()

# %%
gs_category_gb= gs_category_data.groupby(['SI_NM','GU_CODE','DONG_NM'])

# %%
# 시, 구, 동별 합은 1이다.
gs_category_gb.sum().dropna()
# Out:
#                        20190201  20190202  20190203  20190204  20190205  \
# SI_NM GU_CODE DONG_NM
# 대구    11      남산1동        1.001     1.000     1.001     1.001     1.001
#               남산4동        1.000     1.000     0.999     1.001     1.000
#               동인동         1.001     1.001     1.001     1.000     1.000
#               삼덕동         0.999     0.999     0.999     1.000     1.001
#               성내1동        1.000     1.000     1.001     0.998     1.000
#               성내2동        1.000     1.001     0.999     1.001     0.999
#               성내3동        0.999     0.999     0.998     1.000     1.000
#       26      고산1동        1.000     0.999     1.001     1.000     1.000
#               고산2동        1.001     0.999     1.000     1.002     1.001
#               고산3동        1.001     1.000     1.000     1.001     1.000
#               두산동         0.999     1.000     0.999     1.000     1.000
#               만촌1동        1.000     1.000     0.999     0.999     1.001
#               만촌3동        1.000     1.000     1.001     1.000     1.000
#               범물1동        1.000     1.000     1.000     0.999     0.999
#               범물2동        1.000     1.000     1.000     1.001     0.999
#               범어1동        0.999     0.999     1.000     0.999     1.000
#               범어2동        1.001     1.001     1.000     0.999     1.000
#               범어3동        1.000     1.000     1.000     1.000     1.002
#               범어4동        1.000     1.001     0.999     1.000     0.999
#               수성1가동       1.001     1.000     0.999     1.001     0.999
#               수성2.3가동     0.998     1.000     1.000     0.999     1.001
#               수성4가동       1.000     0.999     1.000     1.000     1.001
#               중동          1.000     1.000     1.001     1.002     1.000
#               지산1동        1.000     1.000     0.999     1.000     1.000
#               지산2동        1.000     1.000     1.000     0.999     0.999
#               황금1동        1.000     1.000     1.001     1.000     0.999
#               황금2동        1.000     0.999     0.999     1.001     1.001
# 서울    14      광희동         0.998     0.999     1.000     0.999     1.002
#               다산동         1.000     0.999     1.000     0.999     1.001
#               동화동         1.000     1.000     1.001     1.000     0.998
#               명동          0.999     1.000     1.000     1.000     1.001
#               소공동         1.001     1.001     1.001     1.000     1.000
#               신당동         0.999     1.001     1.000     1.000     1.001
#               신당제5동       1.001     0.999     1.000     0.999     1.000
#               약수동         1.000     1.000     1.000     1.000     1.000
#               을지로동        1.000     1.001     1.001     1.000     1.000
#               장충동         0.998     1.001     1.000     1.001     0.999
#               중림동         1.002     0.998     1.002     1.000     1.000
#               청구동         1.000     1.000     1.001     1.001     1.000
#               필동          0.999     0.999     1.000     1.001     1.000
#               황학동         1.001     1.001     1.000     0.999     0.999
#               회현동         1.001     1.001     1.000     1.000     1.001
#       35      공릉1동        1.000     1.001     1.000     1.000     0.999
#               공릉2동        1.000     0.998     0.999     1.000     1.002
#               상계10동       1.000     1.001     1.000     1.002     1.001
#               상계1동        1.000     1.000     1.001     0.999     1.000
#               상계2동        1.001     1.001     1.001     1.000     1.001
#               상계3.4동      1.000     0.999     0.999     1.001     0.999
#               상계5동        1.000     1.001     1.000     1.000     1.000
#               상계6.7동      1.001     1.000     1.000     1.001     1.000
#               상계9동        1.000     0.999     0.999     0.998     0.999
#               월계1동        1.001     1.000     0.999     1.000     0.999
#               월계2동        0.999     0.999     1.001     1.001     1.001
#               월계3동        1.000     0.999     0.999     1.000     1.001
#               중계1동        1.000     1.001     0.999     1.000     1.000
#               중계2.3동      1.001     1.001     1.000     1.000     1.000
#               중계4동        1.001     0.999     1.000     1.000     1.000
#               중계본동        1.002     1.000     1.000     1.000     1.000
#               하계1동        1.000     1.001     1.000     1.000     1.001
#               하계2동        1.000     1.000     1.001     1.001     1.001
#
#                        20190206  20190207  20190208  20190209  20190210  ...  \
# SI_NM GU_CODE DONG_NM                                                    ...
# 대구    11      남산1동        1.000     1.000     1.001     1.000     0.999  ...
#               남산4동        1.001     1.000     1.001     0.999     1.000  ...
#               동인동         1.001     1.000     1.001     1.000     1.000  ...
#               삼덕동         1.001     1.000     0.999     1.000     0.999  ...
#               성내1동        0.999     1.001     1.000     1.001     1.001  ...
#               성내2동        1.001     1.000     1.001     0.999     1.000  ...
#               성내3동        1.001     1.001     1.000     1.001     1.000  ...
#       26      고산1동        0.999     1.000     1.000     0.999     1.000  ...
#               고산2동        1.000     1.000     1.001     1.001     1.000  ...
#               고산3동        1.000     1.000     1.000     1.000     1.000  ...
#               두산동         0.999     0.999     1.000     1.000     1.001  ...
#               만촌1동        1.000     1.000     1.000     1.000     1.001  ...
#               만촌3동        1.001     1.000     1.000     1.001     0.998  ...
#               범물1동        1.000     1.000     1.000     1.001     1.000  ...
#               범물2동        1.000     1.000     1.000     1.001     1.001  ...
#               범어1동        1.001     1.001     1.001     1.000     0.999  ...
#               범어2동        1.001     1.000     1.000     1.000     1.000  ...
#               범어3동        1.000     0.999     1.002     1.000     1.000  ...
#               범어4동        1.000     1.000     1.001     0.999     1.000  ...
#               수성1가동       1.001     1.001     1.001     1.000     0.999  ...
#               수성2.3가동     1.001     1.001     1.000     1.000     1.000  ...
#               수성4가동       0.999     1.000     1.000     1.001     1.000  ...
#               중동          0.999     1.000     1.001     0.999     0.999  ...
#               지산1동        1.001     1.000     0.999     0.999     1.000  ...
#               지산2동        0.998     1.002     0.999     1.000     0.999  ...
#               황금1동        1.000     1.001     1.000     0.999     1.000  ...
#               황금2동        1.000     1.001     1.000     1.000     1.001  ...
# 서울    14      광희동         1.000     1.000     1.000     1.001     1.000  ...
#               다산동         1.000     1.000     0.999     1.001     1.001  ...
#               동화동         1.001     1.001     1.000     1.000     1.001  ...
#               명동          1.001     1.000     1.000     1.000     1.000  ...
#               소공동         0.998     0.999     1.000     0.999     0.999  ...
#               신당동         1.001     1.000     0.998     0.999     1.000  ...
#               신당제5동       1.001     1.000     1.000     1.000     1.000  ...
#               약수동         1.001     1.000     1.000     1.000     1.000  ...
#               을지로동        1.000     1.001     1.002     0.999     0.999  ...
#               장충동         1.000     1.001     1.000     0.999     1.000  ...
#               중림동         0.999     1.000     1.001     1.000     0.999  ...
#               청구동         1.002     0.998     1.000     1.001     0.999  ...
#               필동          1.001     1.001     1.000     1.000     1.000  ...
#               황학동         0.999     0.999     1.000     1.000     1.000  ...
#               회현동         1.001     1.001     1.001     0.999     1.001  ...
#       35      공릉1동        1.000     1.001     1.001     1.001     0.999  ...
#               공릉2동        1.000     1.000     1.000     1.000     1.000  ...
#               상계10동       1.000     1.000     1.000     1.001     1.001  ...
#               상계1동        1.002     1.000     1.001     1.000     1.001  ...
#               상계2동        1.001     1.001     1.000     1.001     1.000  ...
#               상계3.4동      0.999     1.001     1.000     1.000     1.000  ...
#               상계5동        1.000     1.001     1.000     1.000     1.000  ...
#               상계6.7동      0.999     1.002     1.002     1.001     1.000  ...
#               상계9동        0.999     1.000     1.001     1.000     1.000  ...
#               월계1동        1.000     1.000     1.000     1.001     0.998  ...
#               월계2동        0.999     1.000     0.999     1.000     1.000  ...
#               월계3동        1.001     1.001     1.001     1.001     1.001  ...
#               중계1동        1.001     0.999     1.001     1.000     1.000  ...
#               중계2.3동      1.000     0.999     1.000     0.999     1.000  ...
#               중계4동        1.000     0.999     0.999     1.001     0.999  ...
#               중계본동        1.001     1.000     0.999     0.999     1.001  ...
#               하계1동        1.001     1.001     1.000     1.001     1.000  ...
#               하계2동        1.000     1.000     0.999     1.000     1.000  ...
#
#                        20200522  20200523  20200524  20200525  20200526  \
# SI_NM GU_CODE DONG_NM
# 대구    11      남산1동        0.999     1.001     1.000     1.000     1.000
#               남산4동        1.000     1.001     1.001     1.000     1.000
#               동인동         1.000     1.000     1.000     1.001     0.998
#               삼덕동         1.000     1.000     0.999     0.999     0.999
#               성내1동        0.999     1.000     1.000     1.001     0.999
#               성내2동        1.001     1.000     1.001     0.999     1.000
#               성내3동        1.000     1.000     0.999     1.001     1.000
#       26      고산1동        1.000     1.001     1.000     1.000     1.001
#               고산2동        1.002     1.001     0.999     1.000     0.999
#               고산3동        0.999     1.000     1.001     1.000     1.000
#               두산동         1.001     0.999     1.001     1.000     0.999
#               만촌1동        1.001     1.001     0.999     0.999     1.000
#               만촌3동        0.999     1.000     1.000     0.999     1.000
#               범물1동        1.001     1.000     1.000     1.001     0.999
#               범물2동        1.000     1.000     1.000     0.999     1.000
#               범어1동        0.999     1.001     1.001     1.001     1.001
#               범어2동        1.001     1.000     1.001     0.998     1.001
#               범어3동        1.001     1.000     1.000     0.999     1.000
#               범어4동        1.001     1.000     0.999     0.999     1.000
#               수성1가동       1.001     1.000     1.001     1.000     0.999
#               수성2.3가동     1.000     1.000     1.000     1.000     1.001
#               수성4가동       1.001     0.999     0.999     0.999     1.001
#               중동          1.000     1.000     1.000     0.999     1.000
#               지산1동        0.999     1.001     1.001     0.998     1.001
#               지산2동        1.002     1.000     1.001     1.000     1.000
#               황금1동        1.000     0.999     1.000     1.000     0.998
#               황금2동        1.001     1.001     1.000     0.999     1.000
# 서울    14      광희동         1.000     1.000     1.000     1.000     1.000
#               다산동         1.000     0.999     0.999     1.000     0.999
#               동화동         1.000     1.001     0.999     1.002     0.999
#               명동          1.000     1.000     1.000     1.000     0.999
#               소공동         1.000     0.999     1.000     1.000     0.999
#               신당동         1.000     1.001     1.000     1.000     1.001
#               신당제5동       1.001     1.001     1.000     1.000     1.002
#               약수동         1.001     1.000     1.000     0.998     1.000
#               을지로동        0.999     1.000     1.000     1.002     1.000
#               장충동         1.000     1.000     1.000     1.000     1.001
#               중림동         1.001     1.001     1.000     1.000     0.999
#               청구동         0.999     1.000     1.000     1.000     1.000
#               필동          0.999     1.000     1.000     1.001     1.001
#               황학동         0.999     0.998     1.000     1.001     1.001
#               회현동         1.000     1.000     1.001     0.999     0.999
#       35      공릉1동        0.999     1.002     1.001     0.999     1.000
#               공릉2동        1.002     1.000     0.998     1.001     0.999
#               상계10동       1.000     1.000     1.000     1.000     1.001
#               상계1동        0.999     0.999     1.000     0.999     0.999
#               상계2동        0.998     1.001     1.001     1.000     1.000
#               상계3.4동      0.999     0.999     1.000     1.000     1.001
#               상계5동        1.000     1.000     1.000     1.001     1.002
#               상계6.7동      1.000     0.999     0.999     1.000     1.000
#               상계9동        1.001     1.001     1.000     1.000     0.999
#               월계1동        1.000     1.000     1.000     1.000     1.000
#               월계2동        1.000     1.000     0.999     1.000     0.999
#               월계3동        1.000     0.999     1.001     1.001     1.000
#               중계1동        1.000     1.001     0.998     1.000     1.001
#               중계2.3동      0.999     1.000     0.998     1.000     1.001
#               중계4동        1.001     0.999     1.000     1.001     0.999
#               중계본동        1.001     1.000     1.001     1.000     1.000
#               하계1동        1.000     1.001     0.999     0.999     1.000
#               하계2동        1.000     1.000     1.000     1.001     0.999
#
#                        20200527  20200528  20200529  20200530  20200531
# SI_NM GU_CODE DONG_NM
# 대구    11      남산1동        0.999     1.000     0.999     0.999     1.001
#               남산4동        0.999     1.000     1.000     1.000     1.000
#               동인동         1.002     1.000     1.000     0.998     1.000
#               삼덕동         0.999     1.000     0.999     1.000     0.998
#               성내1동        1.000     1.001     0.999     0.999     1.000
#               성내2동        1.000     1.000     1.000     0.999     1.000
#               성내3동        1.000     0.999     1.001     1.001     1.001
#       26      고산1동        1.000     0.999     1.000     1.000     1.000
#               고산2동        1.000     1.001     1.001     1.000     1.000
#               고산3동        0.999     1.001     1.000     0.999     1.000
#               두산동         1.000     1.001     1.001     0.999     1.000
#               만촌1동        1.001     1.000     1.000     1.000     0.998
#               만촌3동        1.001     1.000     1.000     0.999     1.000
#               범물1동        1.000     0.999     1.000     1.000     1.000
#               범물2동        0.999     1.000     1.000     0.999     0.999
#               범어1동        0.999     1.000     1.000     1.000     1.000
#               범어2동        1.000     0.999     1.000     0.999     1.000
#               범어3동        1.001     1.000     1.001     1.001     1.000
#               범어4동        1.000     1.001     1.002     0.999     0.999
#               수성1가동       1.001     0.999     1.001     1.001     0.999
#               수성2.3가동     1.000     0.999     1.001     0.999     1.000
#               수성4가동       0.999     0.999     0.999     1.001     1.000
#               중동          1.001     1.001     1.001     1.000     1.000
#               지산1동        1.001     1.000     1.000     1.000     1.001
#               지산2동        0.999     0.999     1.000     0.998     1.001
#               황금1동        1.001     1.000     1.001     1.000     1.001
#               황금2동        0.999     1.001     1.000     0.999     1.000
# 서울    14      광희동         1.001     1.000     1.000     1.001     1.000
#               다산동         1.000     1.000     1.001     1.001     1.000
#               동화동         1.000     1.001     1.000     1.001     1.001
#               명동          1.000     1.001     1.001     0.999     1.000
#               소공동         1.000     1.000     1.000     1.000     1.001
#               신당동         1.001     0.999     1.001     1.000     1.000
#               신당제5동       1.001     1.000     0.999     1.000     1.000
#               약수동         0.999     1.001     1.000     1.001     0.999
#               을지로동        1.000     1.000     1.000     1.000     1.000
#               장충동         0.999     1.000     0.999     1.000     1.000
#               중림동         1.000     1.001     1.000     1.000     0.999
#               청구동         1.000     0.998     1.001     0.999     1.000
#               필동          1.000     0.999     1.000     1.000     0.999
#               황학동         1.001     1.001     1.000     1.000     1.000
#               회현동         1.001     0.999     0.998     0.999     1.000
#       35      공릉1동        1.000     1.001     1.000     0.999     1.000
#               공릉2동        1.001     1.000     0.999     0.999     1.001
#               상계10동       1.001     1.001     1.000     1.000     0.999
#               상계1동        1.000     1.000     1.000     1.001     1.001
#               상계2동        1.001     0.999     1.000     1.000     1.001
#               상계3.4동      1.000     0.999     1.000     0.999     1.000
#               상계5동        1.000     0.999     0.998     1.000     1.000
#               상계6.7동      1.000     1.001     1.001     1.001     1.000
#               상계9동        1.000     1.001     1.000     0.998     1.000
#               월계1동        0.999     1.000     1.000     0.999     1.001
#               월계2동        1.000     1.000     1.001     1.000     1.000
#               월계3동        1.000     1.000     0.999     1.001     0.999
#               중계1동        1.000     0.999     1.000     0.998     0.999
#               중계2.3동      1.000     1.001     1.000     1.001     0.999
#               중계4동        1.000     1.000     1.000     1.001     1.000
#               중계본동        1.000     1.000     0.999     1.001     1.000
#               하계1동        0.999     1.000     0.999     1.000     1.000
#               하계2동        1.000     0.999     1.000     0.999     1.000
#
# [60 rows x 241 columns]

# %%
gs_category_gb2= gs_category_data.groupby('ITEM_CODE')

# %%
# 업종별 전체 합 파이플랏
plt.pie(gs_category_gb2.sum().sum(axis= 1), labels= gs['ITEM_CODE_DICT'].values())
# Out:
# ([<matplotlib.patches.Wedge at 0x2250bc98040>,
#   <matplotlib.patches.Wedge at 0x22511bb5df0>,
#   <matplotlib.patches.Wedge at 0x22511bb57f0>,
#   <matplotlib.patches.Wedge at 0x22511bb5100>,
#   <matplotlib.patches.Wedge at 0x22511bb5f10>,
#   <matplotlib.patches.Wedge at 0x225319d87c0>,
#   <matplotlib.patches.Wedge at 0x225032be490>,
#   <matplotlib.patches.Wedge at 0x22510d61d00>],
#  [Text(0.59327524928022, 0.9262961074038328, '식사'),
#   Text(-0.9937266930029731, 0.4717067517148499, '간식'),
#   Text(-0.23097590967892512, -1.0754766985611512, '마실거리'),
#   Text(0.9162500689599474, -0.6086754563237226, '홈&리빙'),
#   Text(1.048551184173605, -0.3324761858661922, '헬스&뷰티'),
#   Text(1.0945578906100637, -0.10928414387846053, '취미&여가활동'),
#   Text(1.0983096158980563, -0.06095890112087295, '사회활동'),
#   Text(1.0998822612277406, -0.016093832251892815, '임신/육아')])

# %%
# 일자별 파이플랏.
plt.pie(gs_category_gb2.sum()['20190201'], labels= gs['ITEM_CODE_DICT'].values())
plt.title('20190201')
# Out:
# Text(0.5, 1.0, '20190201')

# %%
plt.figure(figsize= (30,15))
plt.plot(gs_category_gb2.sum())
# Out:
# [<matplotlib.lines.Line2D at 0x2b3430a7f10>,
#  <matplotlib.lines.Line2D at 0x2b3430b39d0>,
#  <matplotlib.lines.Line2D at 0x2b3430c0490>,
#  <matplotlib.lines.Line2D at 0x2b3430c0f10>,
#  <matplotlib.lines.Line2D at 0x2b3430cc9d0>,
#  <matplotlib.lines.Line2D at 0x2b3430d8490>,
#  <matplotlib.lines.Line2D at 0x2b3430d8f10>,
#  <matplotlib.lines.Line2D at 0x2b3430e69d0>,
#  <matplotlib.lines.Line2D at 0x2b3430f0490>,
#  <matplotlib.lines.Line2D at 0x2b3430f0f10>,
#  <matplotlib.lines.Line2D at 0x2b33f2b9cd0>,
#  <matplotlib.lines.Line2D at 0x2b3430fdf10>,
#  <matplotlib.lines.Line2D at 0x2b343109c70>,
#  <matplotlib.lines.Line2D at 0x2b343115730>,
#  <matplotlib.lines.Line2D at 0x2b343115c70>,
#  <matplotlib.lines.Line2D at 0x2b343121c70>,
#  <matplotlib.lines.Line2D at 0x2b34312f730>,
#  <matplotlib.lines.Line2D at 0x2b34312fc70>,
#  <matplotlib.lines.Line2D at 0x2b34313ac70>,
#  <matplotlib.lines.Line2D at 0x2b343146730>,
#  <matplotlib.lines.Line2D at 0x2b343146c70>,
#  <matplotlib.lines.Line2D at 0x2b343153c70>,
#  <matplotlib.lines.Line2D at 0x2b34316b1f0>,
#  <matplotlib.lines.Line2D at 0x2b34315e9d0>,
#  <matplotlib.lines.Line2D at 0x2b343177730>,
#  <matplotlib.lines.Line2D at 0x2b33f1d8b20>,
#  <matplotlib.lines.Line2D at 0x2b3433d51c0>,
#  <matplotlib.lines.Line2D at 0x2b3433d5340>,
#  <matplotlib.lines.Line2D at 0x2b3433d54c0>,
#  <matplotlib.lines.Line2D at 0x2b3433d5640>,
#  <matplotlib.lines.Line2D at 0x2b3433d57c0>,
#  <matplotlib.lines.Line2D at 0x2b3433d5940>,
#  <matplotlib.lines.Line2D at 0x2b3433d5ac0>,
#  <matplotlib.lines.Line2D at 0x2b3433d5c40>,
#  <matplotlib.lines.Line2D at 0x2b3433d5dc0>,
#  <matplotlib.lines.Line2D at 0x2b3433d5f40>,
#  <matplotlib.lines.Line2D at 0x2b3433d5df0>,
#  <matplotlib.lines.Line2D at 0x2b3433b21c0>,
#  <matplotlib.lines.Line2D at 0x2b3433b24f0>,
#  <matplotlib.lines.Line2D at 0x2b3433da280>,
#  <matplotlib.lines.Line2D at 0x2b3433da400>,
#  <matplotlib.lines.Line2D at 0x2b3433da520>,
#  <matplotlib.lines.Line2D at 0x2b3433da430>,
#  <matplotlib.lines.Line2D at 0x2b3433da610>,
#  <matplotlib.lines.Line2D at 0x2b3433da790>,
#  <matplotlib.lines.Line2D at 0x2b3433da910>,
#  <matplotlib.lines.Line2D at 0x2b3433daa90>,
#  <matplotlib.lines.Line2D at 0x2b3433dac10>,
#  <matplotlib.lines.Line2D at 0x2b3433dad90>,
#  <matplotlib.lines.Line2D at 0x2b3433e1070>,
#  <matplotlib.lines.Line2D at 0x2b3433e10d0>,
#  <matplotlib.lines.Line2D at 0x2b3433e1250>,
#  <matplotlib.lines.Line2D at 0x2b3433e13d0>,
#  <matplotlib.lines.Line2D at 0x2b3433e1550>,
#  <matplotlib.lines.Line2D at 0x2b3433e16d0>,
#  <matplotlib.lines.Line2D at 0x2b3433e1850>,
#  <matplotlib.lines.Line2D at 0x2b3433e19d0>,
#  <matplotlib.lines.Line2D at 0x2b3433e1b50>,
#  <matplotlib.lines.Line2D at 0x2b3433e1cd0>,
#  <matplotlib.lines.Line2D at 0x2b3433e1d90>,
#  <matplotlib.lines.Line2D at 0x2b3433e7040>,
#  <matplotlib.lines.Line2D at 0x2b3433e7190>,
#  <matplotlib.lines.Line2D at 0x2b3433e7310>,
#  <matplotlib.lines.Line2D at 0x2b3433e7490>,
#  <matplotlib.lines.Line2D at 0x2b3433e7610>,
#  <matplotlib.lines.Line2D at 0x2b3433e7790>,
#  <matplotlib.lines.Line2D at 0x2b3433e7910>,
#  <matplotlib.lines.Line2D at 0x2b3433e7a90>,
#  <matplotlib.lines.Line2D at 0x2b3433e7c10>,
#  <matplotlib.lines.Line2D at 0x2b3433e7d90>,
#  <matplotlib.lines.Line2D at 0x2b3433ec070>,
#  <matplotlib.lines.Line2D at 0x2b3433ec0d0>,
#  <matplotlib.lines.Line2D at 0x2b3433ec250>,
#  <matplotlib.lines.Line2D at 0x2b3433ec3d0>,
#  <matplotlib.lines.Line2D at 0x2b3433ec550>,
#  <matplotlib.lines.Line2D at 0x2b3433ec6d0>,
#  <matplotlib.lines.Line2D at 0x2b3433ec850>,
#  <matplotlib.lines.Line2D at 0x2b3433ec9d0>,
#  <matplotlib.lines.Line2D at 0x2b3433ecb50>,
#  <matplotlib.lines.Line2D at 0x2b3433eccd0>,
#  <matplotlib.lines.Line2D at 0x2b3433ecd90>,
#  <matplotlib.lines.Line2D at 0x2b3433f2040>,
#  <matplotlib.lines.Line2D at 0x2b3433f2190>,
#  <matplotlib.lines.Line2D at 0x2b3433f2310>,
#  <matplotlib.lines.Line2D at 0x2b3433f2490>,
#  <matplotlib.lines.Line2D at 0x2b3433f2610>,
#  <matplotlib.lines.Line2D at 0x2b3433f2790>,
#  <matplotlib.lines.Line2D at 0x2b3433f2910>,
#  <matplotlib.lines.Line2D at 0x2b3433f2a90>,
#  <matplotlib.lines.Line2D at 0x2b3433f2c10>,
#  <matplotlib.lines.Line2D at 0x2b3433f2d90>,
#  <matplotlib.lines.Line2D at 0x2b3433f8070>,
#  <matplotlib.lines.Line2D at 0x2b3433f80d0>,
#  <matplotlib.lines.Line2D at 0x2b3433f8250>,
#  <matplotlib.lines.Line2D at 0x2b3433f83d0>,
#  <matplotlib.lines.Line2D at 0x2b3433f8550>,
#  <matplotlib.lines.Line2D at 0x2b3433f86d0>,
#  <matplotlib.lines.Line2D at 0x2b3433f8850>,
#  <matplotlib.lines.Line2D at 0x2b3433f89d0>,
#  <matplotlib.lines.Line2D at 0x2b3433f8b50>,
#  <matplotlib.lines.Line2D at 0x2b3433f8cd0>,
#  <matplotlib.lines.Line2D at 0x2b3433f8d90>,
#  <matplotlib.lines.Line2D at 0x2b3433fe040>,
#  <matplotlib.lines.Line2D at 0x2b3433fe190>,
#  <matplotlib.lines.Line2D at 0x2b3433fe310>,
#  <matplotlib.lines.Line2D at 0x2b3433fe490>,
#  <matplotlib.lines.Line2D at 0x2b3433fe610>,
#  <matplotlib.lines.Line2D at 0x2b3433fe790>,
#  <matplotlib.lines.Line2D at 0x2b3433fe910>,
#  <matplotlib.lines.Line2D at 0x2b3433fea90>,
#  <matplotlib.lines.Line2D at 0x2b3433fec10>,
#  <matplotlib.lines.Line2D at 0x2b3433fed90>,
#  <matplotlib.lines.Line2D at 0x2b343404070>,
#  <matplotlib.lines.Line2D at 0x2b3434040d0>,
#  <matplotlib.lines.Line2D at 0x2b343404250>,
#  <matplotlib.lines.Line2D at 0x2b3434043d0>,
#  <matplotlib.lines.Line2D at 0x2b343404550>,
#  <matplotlib.lines.Line2D at 0x2b3434046d0>,
#  <matplotlib.lines.Line2D at 0x2b343404850>,
#  <matplotlib.lines.Line2D at 0x2b3434049d0>,
#  <matplotlib.lines.Line2D at 0x2b343404b50>,
#  <matplotlib.lines.Line2D at 0x2b343404cd0>,
#  <matplotlib.lines.Line2D at 0x2b343404d90>,
#  <matplotlib.lines.Line2D at 0x2b34340a040>,
#  <matplotlib.lines.Line2D at 0x2b34340a190>,
#  <matplotlib.lines.Line2D at 0x2b34340a310>,
#  <matplotlib.lines.Line2D at 0x2b34340a490>,
#  <matplotlib.lines.Line2D at 0x2b34340a610>,
#  <matplotlib.lines.Line2D at 0x2b34340a790>,
#  <matplotlib.lines.Line2D at 0x2b34340a910>,
#  <matplotlib.lines.Line2D at 0x2b34340aa90>,
#  <matplotlib.lines.Line2D at 0x2b34340ac10>,
#  <matplotlib.lines.Line2D at 0x2b34340ad90>,
#  <matplotlib.lines.Line2D at 0x2b33ee8c850>,
#  <matplotlib.lines.Line2D at 0x2b3433c43d0>,
#  <matplotlib.lines.Line2D at 0x2b3433c4070>,
#  <matplotlib.lines.Line2D at 0x2b343184490>,
#  <matplotlib.lines.Line2D at 0x2b33f172640>,
#  <matplotlib.lines.Line2D at 0x2b33f172e80>,
#  <matplotlib.lines.Line2D at 0x2b33f172c10>,
#  <matplotlib.lines.Line2D at 0x2b34342c460>,
#  <matplotlib.lines.Line2D at 0x2b34342c310>,
#  <matplotlib.lines.Line2D at 0x2b34342c520>,
#  <matplotlib.lines.Line2D at 0x2b34342c640>,
#  <matplotlib.lines.Line2D at 0x2b34342c700>,
#  <matplotlib.lines.Line2D at 0x2b34342c7c0>,
#  <matplotlib.lines.Line2D at 0x2b34342c880>,
#  <matplotlib.lines.Line2D at 0x2b34342c940>,
#  <matplotlib.lines.Line2D at 0x2b34342ca00>,
#  <matplotlib.lines.Line2D at 0x2b34342cac0>,
#  <matplotlib.lines.Line2D at 0x2b34342cb80>,
#  <matplotlib.lines.Line2D at 0x2b34342cc40>,
#  <matplotlib.lines.Line2D at 0x2b34342cd00>,
#  <matplotlib.lines.Line2D at 0x2b34342cdc0>,
#  <matplotlib.lines.Line2D at 0x2b34342ce80>,
#  <matplotlib.lines.Line2D at 0x2b34342cf40>,
#  <matplotlib.lines.Line2D at 0x2b34342c550>,
#  <matplotlib.lines.Line2D at 0x2b34342c340>,
#  <matplotlib.lines.Line2D at 0x2b34342c130>,
#  <matplotlib.lines.Line2D at 0x2b34342c040>,
#  <matplotlib.lines.Line2D at 0x2b33ef8c3d0>,
#  <matplotlib.lines.Line2D at 0x2b33ef8c490>,
#  <matplotlib.lines.Line2D at 0x2b33ef8ca30>,
#  <matplotlib.lines.Line2D at 0x2b33f1290a0>,
#  <matplotlib.lines.Line2D at 0x2b3433c0a60>,
#  <matplotlib.lines.Line2D at 0x2b3433c01c0>,
#  <matplotlib.lines.Line2D at 0x2b3433c0220>,
#  <matplotlib.lines.Line2D at 0x2b3433c0c70>,
#  <matplotlib.lines.Line2D at 0x2b3433c0cd0>,
#  <matplotlib.lines.Line2D at 0x2b3433c0f70>,
#  <matplotlib.lines.Line2D at 0x2b3433cac10>,
#  <matplotlib.lines.Line2D at 0x2b3433caa90>,
#  <matplotlib.lines.Line2D at 0x2b3433cac70>,
#  <matplotlib.lines.Line2D at 0x2b3433caeb0>,
#  <matplotlib.lines.Line2D at 0x2b3433caa00>,
#  <matplotlib.lines.Line2D at 0x2b3433ca850>,
#  <matplotlib.lines.Line2D at 0x2b3433ca7c0>,
#  <matplotlib.lines.Line2D at 0x2b343410040>,
#  <matplotlib.lines.Line2D at 0x2b343410190>,
#  <matplotlib.lines.Line2D at 0x2b3434105b0>,
#  <matplotlib.lines.Line2D at 0x2b3434106d0>,
#  <matplotlib.lines.Line2D at 0x2b343410b80>,
#  <matplotlib.lines.Line2D at 0x2b343410e80>,
#  <matplotlib.lines.Line2D at 0x2b343410790>,
#  <matplotlib.lines.Line2D at 0x2b343410970>,
#  <matplotlib.lines.Line2D at 0x2b343410b20>,
#  <matplotlib.lines.Line2D at 0x2b3434107f0>,
#  <matplotlib.lines.Line2D at 0x2b34342f0d0>,
#  <matplotlib.lines.Line2D at 0x2b34342f190>,
#  <matplotlib.lines.Line2D at 0x2b34342f250>,
#  <matplotlib.lines.Line2D at 0x2b34342f310>,
#  <matplotlib.lines.Line2D at 0x2b34342f3d0>,
#  <matplotlib.lines.Line2D at 0x2b34342f490>,
#  <matplotlib.lines.Line2D at 0x2b34342f550>,
#  <matplotlib.lines.Line2D at 0x2b34342f610>,
#  <matplotlib.lines.Line2D at 0x2b34342f6d0>,
#  <matplotlib.lines.Line2D at 0x2b34342f790>,
#  <matplotlib.lines.Line2D at 0x2b34342f850>,
#  <matplotlib.lines.Line2D at 0x2b34342f910>,
#  <matplotlib.lines.Line2D at 0x2b34342ff10>,
#  <matplotlib.lines.Line2D at 0x2b3434338e0>,
#  <matplotlib.lines.Line2D at 0x2b34344a5e0>,
#  <matplotlib.lines.Line2D at 0x2b3435fea90>,
#  <matplotlib.lines.Line2D at 0x2b34360e550>,
#  <matplotlib.lines.Line2D at 0x2b34360efd0>,
#  <matplotlib.lines.Line2D at 0x2b34361aa90>,
#  <matplotlib.lines.Line2D at 0x2b343626550>,
#  <matplotlib.lines.Line2D at 0x2b343626fd0>,
#  <matplotlib.lines.Line2D at 0x2b343631a90>,
#  <matplotlib.lines.Line2D at 0x2b34363f550>,
#  <matplotlib.lines.Line2D at 0x2b34363ffd0>,
#  <matplotlib.lines.Line2D at 0x2b34364ca90>,
#  <matplotlib.lines.Line2D at 0x2b343656550>,
#  <matplotlib.lines.Line2D at 0x2b343656fd0>,
#  <matplotlib.lines.Line2D at 0x2b343664a90>,
#  <matplotlib.lines.Line2D at 0x2b343672550>,
#  <matplotlib.lines.Line2D at 0x2b343672fd0>,
#  <matplotlib.lines.Line2D at 0x2b34367aa90>,
#  <matplotlib.lines.Line2D at 0x2b343689550>,
#  <matplotlib.lines.Line2D at 0x2b343689fd0>,
#  <matplotlib.lines.Line2D at 0x2b343695a90>,
#  <matplotlib.lines.Line2D at 0x2b3436a07f0>,
#  <matplotlib.lines.Line2D at 0x2b3436a0d30>,
#  <matplotlib.lines.Line2D at 0x2b3436aed30>,
#  <matplotlib.lines.Line2D at 0x2b3436bb7f0>,
#  <matplotlib.lines.Line2D at 0x2b3436bbd30>,
#  <matplotlib.lines.Line2D at 0x2b3436c6d30>,
#  <matplotlib.lines.Line2D at 0x2b3436d37f0>,
#  <matplotlib.lines.Line2D at 0x2b3436d3d30>,
#  <matplotlib.lines.Line2D at 0x2b3436e0d30>,
#  <matplotlib.lines.Line2D at 0x2b3436eb7f0>,
#  <matplotlib.lines.Line2D at 0x2b3436ebd30>,
#  <matplotlib.lines.Line2D at 0x2b3436f9d30>,
#  <matplotlib.lines.Line2D at 0x2b3437047f0>,
#  <matplotlib.lines.Line2D at 0x2b343704d30>,
#  <matplotlib.lines.Line2D at 0x2b343710d30>,
#  <matplotlib.lines.Line2D at 0x2b34371c7f0>,
#  <matplotlib.lines.Line2D at 0x2b34371cd30>,
#  <matplotlib.lines.Line2D at 0x2b34372ad30>,
#  <matplotlib.lines.Line2D at 0x2b3437337f0>,
#  <matplotlib.lines.Line2D at 0x2b343733d30>]

# %%
sns.lmplot(x= '20190201',y= '20190202', data= gs_category_gb2.sum())

# %% [markdown]
# ## GS_DONG_DATA

# %%
gs_dong_data
# Out:
#    SI_NM GU_NM DONG_NM  20190201  20190202  20190203  20190204  20190205  \
# 0     전체    전체      전체     1.198     1.018     0.964     0.919     1.028
# 1     서울    전체      전체     1.189     1.004     0.954     0.900     1.036
# 2     서울    중구      전체     1.380     1.038     1.013     0.899     1.003
# 3     서울    중구     소공동     1.668     1.115     1.212     1.034     1.113
# 4     서울    중구     회현동     1.217     1.232     1.217     1.264     1.245
# ..   ...   ...     ...       ...       ...       ...       ...       ...
# 62    대구   수성구    범물1동     0.755     0.918     0.820     1.043     1.065
# 63    대구   수성구    범물2동     1.050     0.859     0.886     0.977     1.271
# 64    대구   수성구    고산1동     1.064     0.940     0.944     0.955     0.990
# 65    대구   수성구    고산2동     1.076     1.172     1.154     1.557     1.658
# 66    대구   수성구    고산3동     0.856     0.896     0.924     0.901     0.985
#
#     20190206  20190207  ...  20200526  20200527  20200528  20200529  20200530  \
# 0      0.900     1.062  ...     1.068     1.063     1.076     1.138     1.046
# 1      0.893     1.080  ...     1.143     1.148     1.170     1.226     1.110
# 2      0.893     1.265  ...     1.260     1.243     1.289     1.296     1.003
# 3      1.055     1.834  ...     1.475     1.500     1.567     1.492     0.785
# 4      1.187     1.185  ...     1.254     1.237     1.180     1.232     0.794
# ..       ...       ...  ...       ...       ...       ...       ...       ...
# 62     0.836     0.835  ...     0.949     0.897     0.851     0.965     0.963
# 63     0.814     0.816  ...     0.755     0.757     0.707     0.723     0.819
# 64     0.847     0.876  ...     0.781     0.745     0.733     0.821     0.863
# 65     1.122     1.105  ...     1.077     1.189     1.181     1.134     1.153
# 66     0.804     0.884  ...     0.699     0.653     0.701     0.754     0.788
#
#     20200531  SI_CODE  GU_CODE  DONG_CODE  TOTAL_CODE
# 0      0.929       00       00        000     0000000
# 1      0.978       11       00        000     1100000
# 2      0.850       11       14        000     1114000
# 3      0.680       11       14        520     1114520
# 4      0.774       11       14        540     1114540
# ..       ...      ...      ...        ...         ...
# 62     0.800       27       26        661     2726661
# 63     0.796       27       26        662     2726662
# 64     0.732       27       26        670     2726670
# 65     1.095       27       26        680     2726680
# 66     0.567       27       26        690     2726690
#
# [67 rows x 248 columns]

# %% [markdown]
# # SH_DATA

# %% [markdown]
# ## SH_RESIDENT_DATA

# %%
sh_resident_gb= sh_resident_data.groupby(['SEX','AGE'])

# %%
sh_resident_gb.sum()[['USE_CNT','USE_AMT']].plot.bar()

# %% [markdown]
# ## SH_FOREIGN_DATA

# %%
sh_foreign_data.columns
# Out:
# Index(['DATE', 'YEAR', 'MONTH', 'DAY', 'GU_CODE', 'DONG_CODE', 'INDUSTRY_CODE',
#        'COUNTRY_NM', 'USE_CNT', 'USE_AMT', 'SI_CODE', 'TOTAL_CODE'],
#       dtype='object')

# %%
sh_foreign_gb= sh_foreign_data.groupby('COUNTRY_NM')

# %%
sh_foreign_gb.sum()['USE_CNT'].fillna(0)
# Out:
# COUNTRY_NM
# 네덜란드           388
# 대만          289472
# 독일            3268
# 러시아           1480
# 미국         1275751
# 미주          195877
# 베트남          49307
# 스웨덴           1437
# 싱가폴         151221
# 아시아         231721
# 영국          145957
# 오스트레일리아       1289
# 유럽          384456
# 일본         1548160
# 정보없음           988
# 중국         1416379
# 중동/아프리카      69381
# 카자흐스탄         1887
# 캐나다           1640
# 태국          137953
# 프랑스           3142
# 필리핀          89032
# 홍콩          167739
# Name: USE_CNT, dtype: int64

# %%
sh_foreign_gb.sum()['USE_AMT'].fillna(0).plot.bar()

# %%
sh_foreign_gb.sum()['USE_CNT'].fillna(0).plot.bar()

# %%
plt.pie(sh_foreign_gb.sum()['USE_AMT'], labels= sh_foreign_gb.sum()['USE_AMT'].index)
# Out:
# ([<matplotlib.patches.Wedge at 0x28d6abdfc10>,
#   <matplotlib.patches.Wedge at 0x28d6b087100>,
#   <matplotlib.patches.Wedge at 0x28d6b087580>,
#   <matplotlib.patches.Wedge at 0x28d6b087a00>,
#   <matplotlib.patches.Wedge at 0x28d6b087e80>,
#   <matplotlib.patches.Wedge at 0x28d6b09b340>,
#   <matplotlib.patches.Wedge at 0x28d6b09b7c0>,
#   <matplotlib.patches.Wedge at 0x28d6b09bc40>,
#   <matplotlib.patches.Wedge at 0x28d6ae8d100>,
#   <matplotlib.patches.Wedge at 0x28d6ae8d580>,
#   <matplotlib.patches.Wedge at 0x28d6b04b7c0>,
#   <matplotlib.patches.Wedge at 0x28d6ae8de50>,
#   <matplotlib.patches.Wedge at 0x28d6aeba310>,
#   <matplotlib.patches.Wedge at 0x28d6aeba790>,
#   <matplotlib.patches.Wedge at 0x28d6aebac10>,
#   <matplotlib.patches.Wedge at 0x28d6aed70d0>,
#   <matplotlib.patches.Wedge at 0x28d6aed7550>,
#   <matplotlib.patches.Wedge at 0x28d6aed79d0>,
#   <matplotlib.patches.Wedge at 0x28d6aed7e50>,
#   <matplotlib.patches.Wedge at 0x28d6aef9310>,
#   <matplotlib.patches.Wedge at 0x28d6aef9790>,
#   <matplotlib.patches.Wedge at 0x28d6aef9c10>,
#   <matplotlib.patches.Wedge at 0x28d6af1c0d0>],
#  [Text(1.099999784539145, 0.0006884866264241411, '네덜란드'),
#   Text(1.090846690587399, 0.14161037262333392, '대만'),
#   Text(1.06383201948754, 0.2797524518445955, '독일'),
#   Text(1.0636698401401412, 0.2803684561006224, '러시아'),
#   Text(0.913277668101589, 0.6131263335944104, '미국'),
#   Text(0.6066500696737722, 0.9175923348441876, '미주'),
#   Text(0.5177932747195988, 0.9705102393355539, '베트남'),
#   Text(0.4855393445823201, 0.9870418151540346, '스웨덴'),
#   Text(0.38716839090872895, 1.0296118866258033, '싱가폴'),
#   Text(0.1670199794165106, 1.087246212444867, '아시아'),
#   Text(-0.08815871954981809, 1.096461599951105, '영국'),
#   Text(-0.22093307979042098, 1.0775846019010848, '오스트레일리아'),
#   Text(-0.3342624446263561, 1.047983119192486, '유럽'),
#   Text(-0.8621100594340867, 0.6832029313626776, '일본'),
#   Text(-1.081369852948799, 0.20159176851620988, '정보없음'),
#   Text(-0.3610489393907427, -1.0390590278539618, '중국'),
#   Text(0.9919618659237929, -0.47540683267385586, '중동/아프리카'),
#   Text(1.0093527527460882, -0.4372722498900362, '카자흐스탄'),
#   Text(1.0096162447201604, -0.4366635299600385, '캐나다'),
#   Text(1.0347943740530674, -0.37309597080124135, '태국'),
#   Text(1.056093563932244, -0.30767902791852997, '프랑스'),
#   Text(1.0678687883103428, -0.2639247069764408, '필리핀'),
#   Text(1.0944046880751133, -0.11080784592804896, '홍콩')])

# %%
plt.pie(sh_foreign_gb.sum()['USE_CNT'], labels= sh_foreign_gb.sum()['USE_AMT'].index)
# Out:
# ([<matplotlib.patches.Wedge at 0x28d6aa3a790>,
#   <matplotlib.patches.Wedge at 0x28d6aa3ac40>,
#   <matplotlib.patches.Wedge at 0x28d6ac56100>,
#   <matplotlib.patches.Wedge at 0x28d6ac56580>,
#   <matplotlib.patches.Wedge at 0x28d6ac56a00>,
#   <matplotlib.patches.Wedge at 0x28d6ac56e80>,
#   <matplotlib.patches.Wedge at 0x28d6ad82340>,
#   <matplotlib.patches.Wedge at 0x28d6ad827c0>,
#   <matplotlib.patches.Wedge at 0x28d6ad82c40>,
#   <matplotlib.patches.Wedge at 0x28d6adbd100>,
#   <matplotlib.patches.Wedge at 0x28d6afab220>,
#   <matplotlib.patches.Wedge at 0x28d6adbd9d0>,
#   <matplotlib.patches.Wedge at 0x28d6adbde50>,
#   <matplotlib.patches.Wedge at 0x28d6b171310>,
#   <matplotlib.patches.Wedge at 0x28d6b171790>,
#   <matplotlib.patches.Wedge at 0x28d6b171c10>,
#   <matplotlib.patches.Wedge at 0x28d6b1790d0>,
#   <matplotlib.patches.Wedge at 0x28d6b179550>,
#   <matplotlib.patches.Wedge at 0x28d6b1799d0>,
#   <matplotlib.patches.Wedge at 0x28d6b179e50>,
#   <matplotlib.patches.Wedge at 0x28d6ae1a310>,
#   <matplotlib.patches.Wedge at 0x28d6ae1a790>,
#   <matplotlib.patches.Wedge at 0x28d6ae1ac10>],
#  [Text(1.0999999785193362, 0.00021738781023131705, '네덜란드'),
#   Text(1.0880013709159082, 0.16202782750226713, '대만'),
#   Text(1.0518595623892513, 0.32185627384019255, '독일'),
#   Text(1.0510781219122478, 0.32439910856446863, '러시아'),
#   Text(0.6399329569613269, 0.8946987261613446, '미국'),
#   Text(-0.14115407530285, 1.0909058286696416, '미주'),
#   Text(-0.2759364325793683, 1.0648281951448186, '베트남'),
#   Text(-0.30336289363382624, 1.0573414560898065, '스웨덴'),
#   Text(-0.3845774584078739, 1.030582446233459, '싱가폴'),
#   Text(-0.5770271210137096, 0.9365039784296861, '아시아'),
#   Text(-0.7454276442629094, 0.8089113840023823, '영국'),
#   Text(-0.8039427029006648, 0.7507836775348632, '오스트레일리아'),
#   Text(-0.9350394929058999, 0.579397227044001, '유럽'),
#   Text(-1.0000353406342197, -0.45818044205596586, '일본'),
#   Text(-0.3793828446628719, -1.0325060082999553, '정보없음'),
#   Text(0.39757327473235626, -1.0256390647877014, '중국'),
#   Text(0.99323475414441, -0.47274170871596843, '중동/아프리카'),
#   Text(1.0097371481252981, -0.43638388111362464, '카자흐스탄'),
#   Text(1.010519462208355, -0.4345692309611171, '캐나다'),
#   Text(1.0388384755180597, -0.36168304049722005, '태국'),
#   Text(1.0621272681535354, -0.28615671623204697, '프랑스'),
#   Text(1.0743865634515668, -0.2359947293367642, '필리핀'),
#   Text(1.0959877391983748, -0.09386626405069955, '홍콩')])

# %%
plt.pie(sh_foreign_gb.sum()['USE_AMT']/sh_foreign_gb.sum()['USE_CNT'], labels= sh_foreign_gb.sum()['USE_AMT'].index)
# Out:
# ([<matplotlib.patches.Wedge at 0x28d6e1476d0>,
#   <matplotlib.patches.Wedge at 0x28d6e147b80>,
#   <matplotlib.patches.Wedge at 0x28d6e147fd0>,
#   <matplotlib.patches.Wedge at 0x28d6e1494c0>,
#   <matplotlib.patches.Wedge at 0x28d6e1498e0>,
#   <matplotlib.patches.Wedge at 0x28d6e149d00>,
#   <matplotlib.patches.Wedge at 0x28d6e15e160>,
#   <matplotlib.patches.Wedge at 0x28d6e15e580>,
#   <matplotlib.patches.Wedge at 0x28d6e15e9a0>,
#   <matplotlib.patches.Wedge at 0x28d6e15edc0>,
#   <matplotlib.patches.Wedge at 0x28d6e0bf610>,
#   <matplotlib.patches.Wedge at 0x28d6e16a610>,
#   <matplotlib.patches.Wedge at 0x28d6e16aa30>,
#   <matplotlib.patches.Wedge at 0x28d6e16ae50>,
#   <matplotlib.patches.Wedge at 0x28d6e16d2b0>,
#   <matplotlib.patches.Wedge at 0x28d6e16d6d0>,
#   <matplotlib.patches.Wedge at 0x28d6e16daf0>,
#   <matplotlib.patches.Wedge at 0x28d6e16df10>,
#   <matplotlib.patches.Wedge at 0x28d6e169370>,
#   <matplotlib.patches.Wedge at 0x28d6e169790>,
#   <matplotlib.patches.Wedge at 0x28d6e169bb0>,
#   <matplotlib.patches.Wedge at 0x28d6e169fd0>,
#   <matplotlib.patches.Wedge at 0x28d6e1b5430>],
#  [Text(0.9846428602467722, 0.49038600894097273, '네덜란드'),
#   Text(0.5467041776402285, 0.954523201473239, '대만'),
#   Text(0.403423144672778, 1.023352220079835, '독일'),
#   Text(0.3096214501623451, 1.0555257256928259, '러시아'),
#   Text(0.15183475593358878, 1.089470608548293, '미국'),
#   Text(-0.030105760931272037, 1.0995879424396893, '미주'),
#   Text(-0.32835261934389093, 1.0498497784778573, '베트남'),
#   Text(-0.7239284069060247, 0.8282074991658221, '스웨덴'),
#   Text(-0.9954447100792911, 0.4680703250315663, '싱가폴'),
#   Text(-1.0920956506703376, 0.13163240401562165, '아시아'),
#   Text(-1.0641326090188963, -0.2786068743276749, '영국'),
#   Text(-0.9358695402540379, -0.5780555367996192, '오스트레일리아'),
#   Text(-0.8477907606493512, -0.7008928778048716, '유럽'),
#   Text(-0.7177987032469397, -0.8335256574437357, '일본'),
#   Text(-0.5872904517779863, -0.9301021047446398, '정보없음'),
#   Text(-0.23796467426307505, -1.0739519606587944, '중국'),
#   Text(0.24582783597291652, -1.0721794043260078, '중동/아프리카'),
#   Text(0.4525173854522874, -1.0026106003147115, '카자흐스탄'),
#   Text(0.5493333859431336, -0.9530125031122374, '캐나다'),
#   Text(0.7151995234822858, -0.8357569273483239, '태국'),
#   Text(0.8623081196600341, -0.682952931590733, '프랑스'),
#   Text(0.9782829455618817, -0.5029537537614852, '필리핀'),
#   Text(1.0837099471635785, -0.1886073975715535, '홍콩')])

# %% [markdown]
# # SK_DATA

# %% [markdown]
# ## SK_AGE_DATA

# %%
# 나이대별, 성별 별 유동인구 분포
sk_age_gb= sk_age_data.groupby(['SEX'])
sk_age_gb.sum()[['00-04','05-09','10-14','15-19','20-24','25-29','30-34','35-39','40-44','45-49','50-54','55-59','60-64','65-69','70-00']].plot.barh()

# %%
sk_age_gb2= sk_age_data.groupby('SEX')

# %%
columns= list(sk_age_gb2.sum().columns[3:])

# %%
sk_age_gb2.sum()[columns[0]]
# Out:
# SEX
# F    1585.01
# M    4174.38
# Name: 00-04, dtype: float64

# %%
len(columns)
# Out:
# 15

# %%
fig, axs= plt.subplots(8,2,figsize= (20,20))
axs= axs.ravel()
for ax, column in zip(axs, columns):
    ax.pie(sk_age_gb2.sum()[column])
    ax.set_ylabel('CNT', fontsize= 10)
    ax.set_xlabel(column, fontsize= 10)

# %% [markdown]
# # WS DATA

# %% [markdown]
# ## ws_mention_data

# %%
# 데이터 정제
ws_mention_data= ws_mention_data.replace({'CATEGORY':'BOLG'}, {'CATEGORY': 'BLOG'})

# %%
# 전체 카테고리별 언급량. 블로그 > 카페 > 뉴스 순
# 블로그: 156,243
# 카페: 27,320
# 뉴스: 5,645
ws_mention_gb= ws_mention_data.groupby('CATEGORY')
ws_mention_gb.sum()['CNT'].plot.bar()

# %%
# 카테고리별, 구별 언급량
ws_mention_gb2= ws_mention_data.groupby(['CATEGORY','GU_NM'])
ws_mention_gb2.sum().sort_values('CNT')['CNT'].plot.bar()

# %% [markdown]
# ## ws_sentiment_data

# %%
# 구별 count의 분포
ws_sentiment_gb= ws_sentiment_data.groupby(['GU_NM'])
ws_sentiment_gb.sum().sort_values('CNT').plot.pie(y= 'CNT')

# %%
ws_sentiment_gb2= ws_sentiment_data.groupby(['GU_NM','SENTIMENT'])

# %%
# 긍정이 부정보다 훨씬 많다. 구별 분포는 긍, 부정 모두 대구 수성구 > 서울 중구 > 서울 노원구 > 대구 중구
ws_sentiment_gb2.sum()['CNT'].sort_values().plot.barh()

# %% [markdown]
# ## ws_topic_data

# %%
ws_topic_data
# Out:
#      YEAR  MONTH GU_CODE  GU_NM DONG_CODE DONG_NM  \
# 0    2019      2      14  서울 중구       520     소공동
# 1    2019      3      14  서울 중구       520     소공동
# 2    2019      4      14  서울 중구       520     소공동
# 3    2019      5      14  서울 중구       520     소공동
# 4    2019      2      14  서울 중구       540     회현동
# ..    ...    ...     ...    ...       ...     ...
# 135  2020      5      11  대구 중구       640     남산동
# 136  2020      2      11  대구 중구       680     대봉동
# 137  2020      3      11  대구 중구       680     대봉동
# 138  2020      4      11  대구 중구       680     대봉동
# 139  2020      5      11  대구 중구       680     대봉동
#
#                   TOPIC_WORD_LIST SI_CODE TOTAL_CODE
# 0         [장관, 기념식, 창간, 롯데호텔, 뷔페]      11    1114520
# 1    [총동창회, 서울대, 박물관, 월드비전, 프로그램]      11    1114520
# 2       [기생충, 반민특위, 강원도, 이재민, 푯돌]      11    1114520
# 3       [동계올림픽, 은퇴, 여제, 기자회견, 눈물]      11    1114520
# 4    [회현동, 서울역, 도시재생, 윤동주, 일제강점기]      11    1114540
# ..                            ...     ...        ...
# 135      [등교, 개학, 어린이날, 학생, 원격수업]      27    2711640
# 136    [봉준호, 기념사업, 반월당, 주거타운, 상권]      27    2711680
# 137  [코로나, 대구은행, 태평로, 특별재난지역, 확산]      27    2711680
# 138    [코로나, 카페, 프랜차이즈, 소상공인, 골목]      27    2711680
# 139    [공연, 중구문화원, 김광석, 무대, 실수요자]      27    2711680
#
# [280 rows x 9 columns]

# %%
topiclist_14= []
for column in ws_topic_data.TOPIC_WORD_LIST[ws_topic_data.GU_CODE == '14']:
    topiclist_14.extend(column)

# %%
ws_topic_data.TOPIC_WORD_LIST[(ws_topic_data.GU_CODE == '14') & (ws_topic_data.YEAR == '2019')]
# Out:
# C:\Users\soohan\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# Series([], Name: TOPIC_WORD_LIST, dtype: object)

# %%
# 전체 topic list. 중복제거 시 1403개에서 939개로 축소
topiclist= []
for lists in ws_topic_data['TOPIC_WORD_LIST']:
    for topic in lists:
        topiclist.append(topic)

topiclist= list(set(topiclist))

# %%
# 동별 토픽리스트들 dictionary
dong2topiclist= dict(np.array(ws_topic_data[['DONG_NM','TOPIC_WORD_LIST']]))

# %%
# 토픽이 속한 동 dictionary
topic2dong= {}

for dong, topics in dong2topiclist.items():
    for topic in topics:
        if topic in topiclist:
            topic2dong.setdefault(topic, dong)
        else:
            continue

# %%
topiclist
# Out:
# ['정의기억연대',
#  '보건의료원',
#  '역세권',
#  '경매',
#  '유흥시설',
#  '보강병원',
#  '담보',
#  '계성학교',
#  '선거지원',
#  '고도제한',
#  '보상계획',
#  '응급조치',
#  '카페',
#  '음악회',
#  '전시관',
#  '공적마스크',
#  '연예계',
#  '상품권',
#  '방역작업',
#  '빵집',
#  '장기미집행',
#  '차상위계층',
#  '확충지원',
#  '선거사무소',
#  '흥행',
#  '서울시장',
#  '한옥마을',
#  '경북경찰청',
#  '태극당',
#  '영남제일관',
#  '중구문화예술거버넌스',
#  '어반',
#  '개별주택가격',
#  '대구의료원',
#  '개장',
#  '정비계획',
#  '행정공제회',
#  '장관',
#  '재난안전대책본부',
#  '소방당국',
#  '기자간담회',
#  '녹색교통지역',
#  '안내',
#  '업종',
#  '종로구',
#  '서울경제',
#  '구조조정',
#  '경복궁역',
#  '자가격리자',
#  '수성구의회',
#  '별관',
#  '동산병원',
#  '중기중앙회',
#  '충무아트센터',
#  '드론',
#  '물량',
#  '지석묘',
#  '타입',
#  '개학',
#  '오존주의보',
#  '대구스트리트모터페스티벌',
#  '위약금',
#  '상권',
#  '대구학원총연합회',
#  '운동길',
#  '임대주택',
#  '박물관',
#  '대팍',
#  '이사청소',
#  '학원가',
#  '용비어천가',
#  '산업단지',
#  '전세임차권',
#  '신라호텔',
#  '지자체',
#  '자영업자',
#  '사전투표율',
#  '서울지방경찰청',
#  '재개발구역',
#  '거처',
#  '보호자',
#  '힐링타운',
#  '복지재단',
#  '접촉자',
#  '공공체육시설',
#  '도서관',
#  '질병관리본부장',
#  '상업시설',
#  '투약',
#  '유형문화재',
#  '정비수법',
#  '예비후보',
#  '국회의원',
#  '도시',
#  '폐렴',
#  '공포',
#  '진화',
#  '버닝썬',
#  '주민센터',
#  '전산망',
#  '도시계획위원회',
#  '재입원',
#  '서소문',
#  '맞춤형교육컨설팅',
#  '예비신랑',
#  '연장교량',
#  '두류정수장',
#  '명예시민증',
#  '주거시설',
#  '태평로',
#  '골목정원',
#  '매물',
#  '프로포폴',
#  '삼각산',
#  '질환',
#  '실수요자',
#  '분신',
#  '희망',
#  '마리퀴리',
#  '두산위브',
#  '미화원',
#  '무학숲도서관',
#  '시내버스',
#  '김광석',
#  '대구지부',
#  '황학동',
#  '경찰관',
#  '주거복합단지',
#  '신도시',
#  '신세계조선호텔',
#  '재테크',
#  '대구',
#  '기념식',
#  '주주총회',
#  '만세운동',
#  '등교개학',
#  '숭례문',
#  '대구경부지구회',
#  '신년인사',
#  '추진',
#  '헌책방',
#  '전국연합학력평가',
#  '개발호재',
#  '낙찰가',
#  '긴급구제',
#  '태릉',
#  '월계동',
#  '차량',
#  '일제강점기',
#  '어린이집',
#  '신청사',
#  '보행약자',
#  '약수동',
#  '관리',
#  '시민아파트',
#  '택시',
#  '사유지',
#  '위장문화센터',
#  '로또',
#  '입학식',
#  '사업체',
#  '추락',
#  '가로수길',
#  '퍼스트파크',
#  '조건',
#  '도소매업',
#  '산행',
#  '수성못',
#  '청약경쟁률',
#  '이사장',
#  '우체국',
#  '지역사회',
#  '어린이대공원',
#  '아트피아',
#  '감염',
#  '정책자문단',
#  '서민경제',
#  '천마스크',
#  '다가구주택',
#  '불법',
#  '민주운동',
#  '성곽',
#  '최고',
#  '규제',
#  '남산',
#  '퍼포먼스',
#  '윤미향',
#  '안상수',
#  '회현',
#  '브랜드',
#  '안심불빛',
#  '다세대',
#  '검사',
#  '대기업',
#  '지역아동센터',
#  '강아지',
#  '몽골한국신문',
#  '청약통장',
#  'RNA',
#  '중구청소년수련관',
#  '체육관',
#  '수도권',
#  '수영장',
#  '직업체험',
#  '특별공연',
#  '리뉴얼',
#  '재산피해',
#  '마스크',
#  '정치자금',
#  '폐원',
#  '양도',
#  '무빙워크',
#  '전국재해구호협회',
#  '무소속',
#  '택시요금',
#  '112',
#  '이태원',
#  '지하철역',
#  '도시재생활성',
#  '유산',
#  '수성범물',
#  '수유인테리어업체',
#  '수성레이크',
#  '나들이',
#  '한인소식',
#  '사랑나눔봉사단',
#  '집단감염',
#  '경춘선숲길',
#  '진밭골',
#  '면마스크',
#  '해링턴',
#  '국민의당',
#  '응봉공원',
#  '전국택배연대노동조합원들',
#  '대구여성정치아카데미',
#  '삼성래미안',
#  '납부',
#  '동선',
#  '부활절',
#  '창작',
#  '경기권',
#  '주상복합',
#  '기업은행',
#  '교통섬',
#  '행정복지센터',
#  '세관',
#  '학여울청구아파트',
#  '지상',
#  '수성남부선',
#  '관광객',
#  '개발제한',
#  '대권',
#  '이로움클래스',
#  '호텔',
#  '자부심',
#  '메르스',
#  '기부채납',
#  '입주청소',
#  '마포공덕점',
#  '보건지소',
#  '고인돌',
#  '학생',
#  '서울대',
#  '도봉운전면허시험장',
#  '아쿠아로빅',
#  '나눔위원',
#  '달구벌',
#  '물놀이장',
#  '헌혈',
#  '선호업종',
#  '격리',
#  '그늘막',
#  '국립극장',
#  '공사현장',
#  '선거전',
#  '신당동',
#  '도배장판',
#  '정리',
#  '수출',
#  '전기',
#  '동계올림픽',
#  '활성화구역',
#  '생활유산',
#  '휴관',
#  '홈플러스',
#  '중계동',
#  '심야',
#  '추천',
#  '벌금형',
#  '지구단위계획',
#  '노원청소년직업체험센터',
#  '범어아트스트리트',
#  '초역세권',
#  '여제',
#  '지역분석',
#  '문화재',
#  '볼거리',
#  '동북선',
#  '취소',
#  '부동산',
#  '미래교육연구원',
#  '담뱃불',
#  '금감원장',
#  '경전철',
#  '보건소',
#  '주민설명회',
#  '선별진료소',
#  '청정지역',
#  '국채보상운동',
#  '소규모',
#  '희망정거장',
#  '구립상화어린이집',
#  '구민들',
#  '태릉효성해링턴플레이스',
#  '아이디어',
#  '서울미래유산',
#  '문화도시',
#  '서울대병원',
#  '절단',
#  '생활방역',
#  '충정아파트',
#  '경춘선',
#  '운동량',
#  '네트워킹파티',
#  '헛걸음',
#  '놀이터',
#  '노후간판',
#  '출마',
#  '목록',
#  '교회',
#  '공동명의',
#  '중추도시',
#  '비빔국수',
#  '경로당',
#  '개표결과',
#  '감정가',
#  '이상식',
#  '생각',
#  '기초연금',
#  '플라잉카',
#  '거주자',
#  '부장판사',
#  '특급호텔',
#  '승용차',
#  '파견용역노동자',
#  '고려양조장',
#  '신당역',
#  '정신질환',
#  '국립과학수사연구원',
#  '래미안',
#  '주소',
#  '약수역',
#  '소규모봉제업체',
#  '국토교통부',
#  '확산',
#  '퇴근길',
#  '지가지수',
#  '신년포럼',
#  '현대엔지니어링',
#  '쪽방',
#  '수목원',
#  '호캉스',
#  '남광토건',
#  '도심권',
#  '성곽마을',
#  '쌍용',
#  '선거상황실',
#  '수성시장역',
#  '소녀상',
#  '서울로',
#  '공동육아',
#  '주택',
#  '참여예산',
#  '김부겸',
#  '친일파',
#  '오존농도',
#  '재난문자',
#  '성당',
#  '긴급재난지원금',
#  '석류꽃',
#  '라이브카페',
#  '숲세권',
#  '리스',
#  '무대',
#  '놀이공원',
#  '코로나바이러스',
#  '전태일',
#  '주민자치학교',
#  '구청장',
#  '상가',
#  '수혜지',
#  '잘루스',
#  '가구',
#  '공원',
#  '연수',
#  '주식회사',
#  '원룸',
#  '회복세',
#  '리모델링',
#  '롯데백화점',
#  '힐스테이트',
#  '전통호텔',
#  '남산건강',
#  '몽골문화경제원',
#  '고시원',
#  '여론조사',
#  '민주화운동',
#  '노원구청장',
#  '모델하우스',
#  '더블역세권',
#  '강원도',
#  '여성안심귀갓길',
#  '놀이시설',
#  '공사',
#  '우한',
#  '은평성모병원',
#  '어린이',
#  '노란버스',
#  '정전',
#  '한경아카데미',
#  '지방',
#  '코로나19',
#  '윤석헌',
#  '공용재단실',
#  '주택신축',
#  '바이오클러스터',
#  '후손들',
#  '투표소',
#  '대구참여연대',
#  '분양',
#  '전동휠체어',
#  '인테리어',
#  '월드비전',
#  '강남',
#  '중고',
#  '김소향',
#  '프랜차이즈',
#  '인지',
#  '폐철길',
#  '경쟁률',
#  '리플렛',
#  '손잡이',
#  '한사랑요양병원',
#  '광희동주민센터',
#  '이용수',
#  '임시정부',
#  '기억',
#  '신부',
#  '이사',
#  '한국마사회',
#  '대학병원',
#  '서울권',
#  '정치자금법',
#  '공간',
#  '유동인구',
#  '기부 행렬',
#  '경찰서',
#  '숙박시설',
#  '기공체조',
#  '골목상권',
#  '재단서비스',
#  '호흡기환자',
#  '본점',
#  '방역',
#  '유전자',
#  '공연',
#  '덴마크',
#  '무순위',
#  '마련',
#  '아양아트센터',
#  '꽃다발',
#  '시범아파트',
#  '서문시장',
#  '집합금지',
#  '교육열',
#  '판정',
#  '선착순',
#  '성동구',
#  '하락폭',
#  '주거지역',
#  '서울역세트럴자',
#  '원인',
#  '레이크',
#  '대우건설',
#  '정원',
#  '회현동',
#  '왕세자비',
#  '용지봉',
#  '정책',
#  '상승세',
#  '들불',
#  '창동차량기지',
#  '무증상',
#  '하늘N',
#  '해외명화전',
#  '노원구',
#  '눈물',
#  '민주운동기념회관',
#  '인프라',
#  '벚꽃',
#  '남촌',
#  '스몰웨딩',
#  '부모님',
#  '이재민',
#  '오피스텔',
#  '이탈',
#  '전용면적',
#  '시의원',
#  '다양',
#  '손기정작은도서관',
#  '삼림공원',
#  '참여형',
#  '재개발',
#  '교직원',
#  '클린존',
#  '환자',
#  '동대구역',
#  '아파트값',
#  '소등행사',
#  '놀이키트',
#  '기간',
#  '동산',
#  '공무집행방해',
#  '다산동',
#  '케이블카',
#  '맛집',
#  '중림',
#  '중앙시장',
#  '중앙방역대책본부',
#  '청구동',
#  '펜트하우스',
#  '등록문화재',
#  '이송',
#  '대구국제마라톤대회',
#  '물류센터',
#  '남녀노소',
#  '비용',
#  '창업',
#  '경계선',
#  '치료제',
#  '노선',
#  '지적',
#  '창동',
#  '신라면세점',
#  '아트스페이스',
#  '남산타워',
#  '아침체조교실',
#  '민간위탁',
#  '취업제한',
#  '주거타운',
#  '식후경',
#  '재난',
#  '아트도서관',
#  '지하철',
#  '센트럴',
#  '휴강',
#  '큰절',
#  '영남풍물연구소',
#  '착공',
#  '폐쇄',
#  '세배',
#  '대한적십자사',
#  '손기정도서관',
#  '예절교육',
#  '228',
#  '예비부부',
#  '경과',
#  '손님',
#  '장수경주마목장',
#  '전국여성의정회',
#  '반월당',
#  '기념관',
#  '영남상생포럼',
#  '랜드마크',
#  '선교단체',
#  '직원',
#  '자회사',
#  '접근성',
#  '퇴계로입구',
#  '자동차',
#  '풍선효과',
#  '어린이회관역',
#  '한정판',
#  '경북대병원',
#  '확진자',
#  '무료돌봄',
#  '서울숲',
#  '울란바토르',
#  '생활치료센터',
#  '기념촬영',
#  '대단지',
#  '프레지던트호텔',
#  '주택규제',
#  '고등학교',
#  '황금네거리',
#  '보합세',
#  '플레이스',
#  '강북',
#  '국립대병원',
#  '등록',
#  '유치원',
#  '온라인',
#  '주거단지',
#  '대구장애인돌봄연맹',
#  'SNS',
#  '소상공인시장진흥공단',
#  '한양도성',
#  '감염병',
#  '자유한국당',
#  '이발소',
#  '관광',
#  '혁명',
#  '방문자제',
#  '원격수업',
#  '군국가요',
#  '노동자',
#  '재건축',
#  '저작권',
#  '일반아파트',
#  '할부',
#  '군사분계선',
#  '서울과학기술대학교',
#  '중랑천',
#  '세배정치',
#  '가족친화마을',
#  '투기과열지구',
#  '구리이단상담소',
#  '신축공사',
#  '대구동산병원',
#  '행정조사',
#  '메가시티',
#  '손소독제',
#  '지산',
#  '경찰관계자',
#  '봉산문화회관',
#  '프로그램',
#  '을지로',
#  '협동조합',
#  '수성문화원',
#  '일본인',
#  '상급종합병원',
#  '신천지',
#  '설명회',
#  '도시자연공원구역',
#  '푸르지오',
#  '후보',
#  '도시재생사업',
#  'hausD',
#  '위안부',
#  '소원풍등',
#  '업체',
#  '창조인상',
#  '일일창구',
#  '수성유원지',
#  '공공도서관',
#  '사업자',
#  '르네상스',
#  '국비30억',
#  '음압병실',
#  '자연조건',
#  '한옥호텔',
#  '대구은행',
#  '돗가비',
#  '특별재난지역',
#  '창간',
#  '범어공원',
#  '구급차',
#  '계약면적',
#  '독립유공자',
#  '급매물',
#  '문화예술인',
#  '전세가격',
#  'SPC그룹',
#  '콜센터',
#  '위장교회',
#  '서울역',
#  '의료진',
#  '뮤지컬',
#  '예술감독',
#  '동의',
#  '위안화',
#  '특화',
#  '정책연구',
#  '불암산',
#  '문화축제위원장',
#  '안심음식점',
#  '두류공원',
#  '주민자치위원장',
#  '타월골목',
#  '대구경찰',
#  '등교',
#  '도봉',
#  '도봉면허시험장',
#  '확진환자',
#  '신용불량자',
#  '호텔신라',
#  '대권주자',
#  '특화상가',
#  '소상공인',
#  '에듀타운',
#  '거실',
#  '플래티넘',
#  '쇼핑몰',
#  '폐업',
#  '약국',
#  '봉준호',
#  '클린코디네이터',
#  '이부진',
#  '수제청',
#  '은퇴',
#  '뷔페',
#  '가구점',
#  '초미세먼지',
#  '상승률',
#  '민주의거',
#  '문자',
#  '미세먼지',
#  '빙상장',
#  '축제',
#  '운동전도사',
#  '사전협상',
#  '대구경북연구원',
#  '종교교회',
#  '자가격리',
#  '중구',
#  '김정섭',
#  '광희문',
#  '따릉이',
#  '광운대역세권',
#  '대구환경운동연합',
#  '유권자',
#  '공연거리',
#  '철거',
#  '대교구장',
#  '릴레이',
#  '위생방역물품',
#  '생명과학부',
#  '변사체',
#  '잠원동',
#  '서양호',
#  '통일교회사',
#  '장노년일자리지원센터',
#  '시립노원청소년',
#  '문화역량',
#  '신세계백화점',
#  '주거대체형',
#  '푯돌',
#  '원내대표',
#  '복음방',
#  '숲길',
#  '예방',
#  '땅주인',
#  '삼성',
#  '보존',
#  '롯데호텔',
#  '엘리니티',
#  '확진',
#  '단독주택',
#  '교육청',
#  '백화점',
#  '환원',
#  '기자회견',
#  '어린이날',
#  '센터시티',
#  '편의점',
#  '국채보상운동기념공원',
#  '출산',
#  '사회적경제',
#  '금리단길',
#  '아이',
#  '그랜드호텔',
#  '뉴딜사업',
#  '타임캡슐',
#  '주류',
#  '청정쉼터',
#  '홍준표',
#  '투표',
#  '기념사업',
#  '생활형숙박시설',
#  '미술관',
#  '전수조사',
#  '중국인',
#  '건강걷기',
#  '상승폭',
#  '포스코건설',
#  '지지자들',
#  '옥주현',
#  'Arch',
#  '도심재생문화재단',
#  '배우자',
#  '검찰청',
#  '강북구',
#  '반민특위',
#  '지역도서전',
#  '먹거리',
#  '체험존',
#  '과학관',
#  '총선',
#  '준공청소',
#  '주민',
#  '롯데건설',
#  '선도경제',
#  '신매광장',
#  '고령자',
#  '엘리베이터',
#  '신천지예수교',
#  '매각',
#  '코레일',
#  '견본주택',
#  '봉사',
#  '중도하차',
#  '스마트홈',
#  '이마트',
#  '음주운전',
#  '노인',
#  '투자',
#  '전용다리',
#  '한내교',
#  '대구읍성',
#  '클럽',
#  '각하',
#  '감소율',
#  '백사마을',
#  '예술대안학교',
#  '투숙객',
#  '부속기관',
#  '다산성곽길',
#  '주거환경',
#  '도시재생',
#  '쓰레기',
#  '근린생활시설',
#  '가족들',
#  '특수구조단',
#  '무상',
#  '관사',
#  '도시환경위원회',
#  '개발비전',
#  '연립주택',
#  '광운대',
#  '코로나바이러스감염증',
#  '서울대학교',
#  '동화동',
#  '자유한국장',
#  '수락산',
#  '고령성주칠곡',
#  '원장',
#  '출사표',
#  '이단',
#  '정규직',
#  '완주',
#  '기생충',
#  '명단',
#  '반도체',
#  '공공임대',
#  '몽골',
#  '보증금',
#  '중구문화원',
#  '성벽',
#  '긴급생계자금',
#  '북부역세권',
#  '단속',
#  '임대',
#  '감염증',
#  '사진',
#  '문화체육관광부',
#  '도시공원',
#  '하락세',
#  '자유토론',
#  '조현병',
#  '청약',
#  '학부모',
#  '논란',
#  '공급',
#  '서울시',
#  '식목일',
#  '증발',
#  '화성산업',
#  '계명대학교',
#  '행운보금자리',
#  '합천할매손칼국수',
#  '충무로',
#  '리사이클센터',
#  '기념학생도서관',
#  '유흥업소',
#  '개별공시지가',
#  '몽골인',
#  '국제육상경기연맹',
#  '심은하',
#  '공황장애',
#  '시공사',
#  '공무원',
#  '열쇠고리',
#  '남산둘레길',
#  '어르신',
#  '부동산114',
#  '대구고등보통학교',
#  '소공동',
#  '청소년',
#  '결혼식',
#  '총동창회',
#  '미래통합당',
#  '삼덕동',
#  '선거구',
#  '공원구역',
#  '코로나',
#  '테마상가',
#  '골목',
#  '감사원',
#  '리스트',
#  '주방거리',
#  '상설운영',
#  '보행자',
#  '사망자',
#  '주호영',
#  '아파트',
#  '송해공원',
#  '응급실',
#  '서울시민',
#  '위원장',
#  '중구청',
#  '더불어민주당',
#  '쇼핑',
#  '전통시장',
#  '농마고',
#  'TBC',
#  '윤동주',
#  '학원',
#  '사망',
#  '미르메디타워',
#  '운영',
#  '책거리',
#  '관심도',
#  '원나라',
#  '단지',
#  '정책자금',
#  '성폭행',
#  '비강남권',
#  '왕세자',
#  '범어네거리']

# %%
topic2dong
# Out:
# {'창조인상': '소공동',
#  '생명과학부': '소공동',
#  '예술감독': '소공동',
#  '코로나19': '소공동',
#  'RNA': '소공동',
#  '시민아파트': '회현동',
#  '시범아파트': '회현동',
#  '서울시장': '회현동',
#  '충정아파트': '회현동',
#  '회현': '회현동',
#  '마스크': '명동',
#  '선별진료소': '명동',
#  '면마스크': '명동',
#  '천마스크': '명동',
#  '확진환자': '명동',
#  '본점': '필동',
#  '주류': '필동',
#  '리스': '필동',
#  '양도': '필동',
#  '코로나': '장충동',
#  '신세계조선호텔': '장충동',
#  '브랜드': '장충동',
#  '한옥호텔': '장충동',
#  '특급호텔': '장충동',
#  '증발': '광희동',
#  '관광': '광희동',
#  '노란버스': '광희동',
#  '준공청소': '광희동',
#  '주거단지': '신당동',
#  '원룸': '신당동',
#  '분양': '신당동',
#  '담보': '신당동',
#  '숭례문': '다산동',
#  '남산': '다산동',
#  '성곽': '다산동',
#  '한양도성': '다산동',
#  '광희문': '다산동',
#  '이태원': '약수동',
#  '클럽': '약수동',
#  '전국택배연대노동조합원들': '약수동',
#  '유흥업소': '약수동',
#  '중구': '청구동',
#  '확진자': '청구동',
#  '이로움클래스': '동화동',
#  '아파트': '황학동',
#  '래미안': '황학동',
#  '엘리니티': '황학동',
#  '주방거리': '황학동',
#  '골목정원': '황학동',
#  '마리퀴리': '중림동',
#  '옥주현': '중림동',
#  '김소향': '중림동',
#  '뮤지컬': '중림동',
#  '성폭행': '월계동',
#  '노원구': '월계동',
#  '보행약자': '공릉동',
#  '경춘선': '공릉동',
#  '운동량': '공릉동',
#  '따릉이': '공릉동',
#  '감염': '공릉동',
#  '하락세': '하계동',
#  '연립주택': '하계동',
#  '더블역세권': '하계동',
#  '부동산': '하계동',
#  '동북선': '중계동',
#  '비강남권': '중계동',
#  '경전철': '중계동',
#  '확진': '중계동',
#  '재개발': '상계동',
#  '도봉': '상계동',
#  '롯데건설': '상계동',
#  '강북구': '상계동',
#  '주거시설': '범어동',
#  '학부모': '범어동',
#  '금감원장': '범어동',
#  '이용수': '만촌동',
#  '정의기억연대': '만촌동',
#  '위안부': '만촌동',
#  '윤미향': '만촌동',
#  '더불어민주당': '만촌동',
#  '위안화': '수성동',
#  '전산망': '수성동',
#  '윤석헌': '수성동',
#  '자회사': '수성동',
#  '남광토건': '수성동',
#  '문화도시': '황금동',
#  '수성못': '황금동',
#  '공연거리': '황금동',
#  '행정복지센터': '황금동',
#  '지자체': '황금동',
#  '판정': '중동',
#  '학생': '중동',
#  '폐쇄': '중동',
#  '물류센터': '상동',
#  '미술관': '상동',
#  '삼덕동': '상동',
#  '무증상': '파동',
#  '접촉자': '파동',
#  '생활방역': '파동',
#  '등교개학': '파동',
#  '온라인': '파동',
#  '무소속': '두산동',
#  '홍준표': '두산동',
#  '개발호재': '두산동',
#  '개표결과': '두산동',
#  '사망': '지산동',
#  '노동자': '지산동',
#  '신축공사': '지산동',
#  '공사현장': '지산동',
#  '추락': '지산동',
#  '수성범물': '범물동',
#  '개발비전': '범물동',
#  '펜트하우스': '범물동',
#  '역세권': '범물동',
#  '수혜지': '범물동',
#  '회복세': '고산동',
#  '방문자제': '고산동',
#  '대기업': '고산동',
#  '취업제한': '고산동',
#  '집합금지': '동인동',
#  '방역': '동인동',
#  '긴급구제': '동인동',
#  '유흥시설': '동인동',
#  '원내대표': '삼덕동',
#  '미래통합당': '삼덕동',
#  '개별공시지가': '삼덕동',
#  '코로나바이러스': '성내동',
#  '신천지': '성내동',
#  '교회': '성내동',
#  '부속기관': '성내동',
#  '복음방': '성내동',
#  '서문시장': '대신동',
#  '생활치료센터': '대신동',
#  '긴급생계자금': '대신동',
#  '손소독제': '대신동',
#  '등교': '남산동',
#  '개학': '남산동',
#  '어린이날': '남산동',
#  '원격수업': '남산동',
#  '공연': '대봉동',
#  '중구문화원': '대봉동',
#  '김광석': '대봉동',
#  '무대': '대봉동',
#  '실수요자': '대봉동'}

# %% [markdown]
# # Co-occurence table 먼저 만든 뒤 접근하는 것이 좋겠음.
